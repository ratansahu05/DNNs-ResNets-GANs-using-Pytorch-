# %%
import torch
import torchvision
from torchvision.transforms import ToTensor, Normalize, Compose
from torchvision.datasets import MNIST

mnist = MNIST(root='data', 
              train=True, 
              download=True,
              transform=Compose([ToTensor(), Normalize(mean=(0.5,), std=(0.5,))]))
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to data/MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting data/MNIST/raw/train-images-idx3-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to data/MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting data/MNIST/raw/train-labels-idx1-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to data/MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting data/MNIST/raw/t10k-images-idx3-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to data/MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting data/MNIST/raw/t10k-labels-idx1-ubyte.gz to data/MNIST/raw

# %%
img, label = mnist[0]
print('Label: ', label)
print(img[:,10:15,10:15])
torch.min(img), torch.max(img)
# Out:
# Label:  5
# tensor([[[-0.9922,  0.2078,  0.9843, -0.2941, -1.0000],
#          [-1.0000,  0.0902,  0.9843,  0.4902, -0.9843],
#          [-1.0000, -0.9137,  0.4902,  0.9843, -0.4510],
#          [-1.0000, -1.0000, -0.7255,  0.8902,  0.7647],
#          [-1.0000, -1.0000, -1.0000, -0.3647,  0.8824]]])
# (tensor(-1.), tensor(1.))

# %%
def denorm(x):
    out = (x + 1) / 2
    return out.clamp(0, 1)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

img_norm = denorm(img)
plt.imshow(img_norm[0], cmap='gray')
print('Label:', label)
# Out:
# Label: 5

# %%
from torch.utils.data import DataLoader

batch_size = 100
data_loader = DataLoader(mnist, batch_size, shuffle=True)

# %%
for img_batch, label_batch in data_loader:
    print('first batch')
    print(img_batch.shape)
    plt.imshow(img_batch[0][0], cmap='gray')
    print(label_batch)
    break
# Out:
# first batch
# torch.Size([100, 1, 28, 28])
# tensor([6, 8, 9, 4, 2, 1, 6, 6, 1, 5, 1, 8, 7, 6, 5, 2, 2, 5, 9, 7, 0, 7, 1, 9,
#         2, 1, 6, 2, 8, 1, 2, 2, 1, 9, 6, 9, 9, 2, 6, 9, 8, 5, 4, 8, 0, 1, 4, 9,
#         9, 2, 6, 5, 9, 5, 0, 3, 3, 6, 7, 3, 0, 1, 3, 2, 4, 9, 0, 2, 2, 1, 4, 9,
#         7, 8, 9, 2, 6, 9, 6, 6, 2, 5, 6, 2, 7, 2, 0, 6, 9, 9, 1, 2, 8, 6, 5, 8,
#         4, 0, 6, 0])

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cpu')

# %%
image_size = 784
hidden_size = 256

# %%
import torch.nn as nn

D = nn.Sequential(
    nn.Linear(image_size, hidden_size),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_size, hidden_size),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_size, 1),
    nn.Sigmoid())

# %%
D.to(device);

# %%
latent_size = 64

# %%
G = nn.Sequential(
    nn.Linear(latent_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, image_size),
    nn.Tanh())

# %%
y = G(torch.randn(2, latent_size))
gen_imgs = denorm(y.reshape((-1, 28,28)).detach())

# %%
plt.imshow(gen_imgs[0], cmap='gray');

# %%
plt.imshow(gen_imgs[1], cmap='gray');

# %%
G.to(device);

# %%
criterion = nn.BCELoss()
d_optimizer = torch.optim.Adam(D.parameters(), lr=0.0002)

# %%
def reset_grad():
    d_optimizer.zero_grad()
    g_optimizer.zero_grad()

def train_discriminator(images):
    # Create the labels which are later used as input for the BCE loss
    real_labels = torch.ones(batch_size, 1).to(device)
    fake_labels = torch.zeros(batch_size, 1).to(device)
        
    # Loss for real images
    outputs = D(images)
    d_loss_real = criterion(outputs, real_labels)
    real_score = outputs

    # Loss for fake images
    z = torch.randn(batch_size, latent_size).to(device)
    fake_images = G(z)
    outputs = D(fake_images)
    d_loss_fake = criterion(outputs, fake_labels)
    fake_score = outputs

    # Combine losses
    d_loss = d_loss_real + d_loss_fake
    # Reset gradients
    reset_grad()
    # Compute gradients
    d_loss.backward()
    # Adjust the parameters using backprop
    d_optimizer.step()
    
    return d_loss, real_score, fake_score

# %%
g_optimizer = torch.optim.Adam(G.parameters(), lr=0.0002)

# %%
def train_generator():
    # Generate fake images and calculate loss
    z = torch.randn(batch_size, latent_size).to(device)
    fake_images = G(z)
    labels = torch.ones(batch_size, 1).to(device)
    g_loss = criterion(D(fake_images), labels)

    # Backprop and optimize
    reset_grad()
    g_loss.backward()
    g_optimizer.step()
    return g_loss, fake_images

# %%
import os

sample_dir = 'samples'
if not os.path.exists(sample_dir):
    os.makedirs(sample_dir)

# %%
from IPython.display import Image
from torchvision.utils import save_image

# Save some real images
for images, _ in data_loader:
    images = images.reshape(images.size(0), 1, 28, 28)
    save_image(denorm(images), os.path.join(sample_dir, 'real_images.png'), nrow=10)
    break
   
Image(os.path.join(sample_dir, 'real_images.png'))

# %%
sample_vectors = torch.randn(batch_size, latent_size).to(device)

def save_fake_images(index):
    fake_images = G(sample_vectors)
    fake_images = fake_images.reshape(fake_images.size(0), 1, 28, 28)
    fake_fname = 'fake_images-{0:0=4d}.png'.format(index)
    print('Saving', fake_fname)
    save_image(denorm(fake_images), os.path.join(sample_dir, fake_fname), nrow=10)
    
# Before training
save_fake_images(0)
Image(os.path.join(sample_dir, 'fake_images-0000.png'))
# Out:
# Saving fake_images-0000.png

# %%
# %%time

num_epochs = 300
total_step = len(data_loader)
d_losses, g_losses, real_scores, fake_scores = [], [], [], []

for epoch in range(num_epochs):
    for i, (images, _) in enumerate(data_loader):
        # Load a batch & transform to vectors
        images = images.reshape(batch_size, -1).to(device)
        
        # Train the discriminator and generator
        d_loss, real_score, fake_score = train_discriminator(images)
        g_loss, fake_images = train_generator()
        
        # Inspect the losses
        if (i+1) % 200 == 0:
            d_losses.append(d_loss.item())
            g_losses.append(g_loss.item())
            real_scores.append(real_score.mean().item())
            fake_scores.append(fake_score.mean().item())
            print('Epoch [{}/{}], Step [{}/{}], d_loss: {:.4f}, g_loss: {:.4f}, D(x): {:.2f}, D(G(z)): {:.2f}' 
                  .format(epoch, num_epochs, i+1, total_step, d_loss.item(), g_loss.item(), 
                          real_score.mean().item(), fake_score.mean().item()))
        
    # Sample and save images
    save_fake_images(epoch+1)
# Out:
# Epoch [0/300], Step [200/600], d_loss: 0.0374, g_loss: 4.2330, D(x): 1.00, D(G(z)): 0.03
# Epoch [0/300], Step [400/600], d_loss: 0.0901, g_loss: 5.5602, D(x): 0.97, D(G(z)): 0.04
# Epoch [0/300], Step [600/600], d_loss: 0.0340, g_loss: 5.3368, D(x): 0.98, D(G(z)): 0.01
# Saving fake_images-0001.png
# Epoch [1/300], Step [200/600], d_loss: 0.0506, g_loss: 4.6237, D(x): 0.98, D(G(z)): 0.03
# Epoch [1/300], Step [400/600], d_loss: 0.7525, g_loss: 3.7757, D(x): 0.78, D(G(z)): 0.26
# Epoch [1/300], Step [600/600], d_loss: 0.0687, g_loss: 4.5203, D(x): 0.99, D(G(z)): 0.06
# Saving fake_images-0002.png
# Epoch [2/300], Step [200/600], d_loss: 0.1243, g_loss: 3.9487, D(x): 0.94, D(G(z)): 0.04
# Epoch [2/300], Step [400/600], d_loss: 0.4349, g_loss: 2.9427, D(x): 0.85, D(G(z)): 0.15
# Epoch [2/300], Step [600/600], d_loss: 0.1361, g_loss: 4.4503, D(x): 0.95, D(G(z)): 0.04
# Saving fake_images-0003.png
# Epoch [3/300], Step [200/600], d_loss: 0.1622, g_loss: 3.2146, D(x): 0.98, D(G(z)): 0.12
# Epoch [3/300], Step [400/600], d_loss: 0.4103, g_loss: 2.5360, D(x): 0.84, D(G(z)): 0.11
# Epoch [3/300], Step [600/600], d_loss: 1.0993, g_loss: 3.5004, D(x): 0.72, D(G(z)): 0.27
# Saving fake_images-0004.png
# Epoch [4/300], Step [200/600], d_loss: 0.4065, g_loss: 3.0376, D(x): 0.86, D(G(z)): 0.14
# Epoch [4/300], Step [400/600], d_loss: 0.5596, g_loss: 3.1645, D(x): 0.82, D(G(z)): 0.12
# Epoch [4/300], Step [600/600], d_loss: 0.3922, g_loss: 2.4393, D(x): 0.84, D(G(z)): 0.13
# Saving fake_images-0005.png
# Epoch [5/300], Step [200/600], d_loss: 0.1206, g_loss: 3.6831, D(x): 0.94, D(G(z)): 0.04
# Epoch [5/300], Step [400/600], d_loss: 0.6117, g_loss: 3.0664, D(x): 0.77, D(G(z)): 0.12
# Epoch [5/300], Step [600/600], d_loss: 0.4918, g_loss: 2.9440, D(x): 0.86, D(G(z)): 0.16
# Saving fake_images-0006.png
# Epoch [6/300], Step [200/600], d_loss: 0.3753, g_loss: 3.6631, D(x): 0.85, D(G(z)): 0.11
# Epoch [6/300], Step [400/600], d_loss: 0.2672, g_loss: 2.6722, D(x): 0.93, D(G(z)): 0.10
# Epoch [6/300], Step [600/600], d_loss: 0.2831, g_loss: 3.6110, D(x): 0.91, D(G(z)): 0.13
# Saving fake_images-0007.png
# Epoch [7/300], Step [200/600], d_loss: 0.1518, g_loss: 5.5235, D(x): 0.94, D(G(z)): 0.04
# Epoch [7/300], Step [400/600], d_loss: 0.1631, g_loss: 4.2358, D(x): 0.93, D(G(z)): 0.04
# Epoch [7/300], Step [600/600], d_loss: 0.3085, g_loss: 3.2811, D(x): 0.89, D(G(z)): 0.04
# Saving fake_images-0008.png
# Epoch [8/300], Step [200/600], d_loss: 0.0597, g_loss: 4.7683, D(x): 0.97, D(G(z)): 0.02
# Epoch [8/300], Step [400/600], d_loss: 0.1696, g_loss: 4.7954, D(x): 0.95, D(G(z)): 0.06
# Epoch [8/300], Step [600/600], d_loss: 0.2110, g_loss: 7.6722, D(x): 0.95, D(G(z)): 0.05
# Saving fake_images-0009.png
# Epoch [9/300], Step [200/600], d_loss: 0.2684, g_loss: 6.1003, D(x): 0.94, D(G(z)): 0.08
# Epoch [9/300], Step [400/600], d_loss: 0.2781, g_loss: 4.6594, D(x): 0.92, D(G(z)): 0.07
# Epoch [9/300], Step [600/600], d_loss: 0.1874, g_loss: 3.3764, D(x): 0.99, D(G(z)): 0.12
# Saving fake_images-0010.png
# Epoch [10/300], Step [200/600], d_loss: 0.1734, g_loss: 2.8843, D(x): 0.97, D(G(z)): 0.07
# Epoch [10/300], Step [400/600], d_loss: 0.1634, g_loss: 6.1005, D(x): 0.94, D(G(z)): 0.05
# Epoch [10/300], Step [600/600], d_loss: 0.0838, g_loss: 6.5649, D(x): 0.97, D(G(z)): 0.01
# Saving fake_images-0011.png
# Epoch [11/300], Step [200/600], d_loss: 0.1833, g_loss: 4.0519, D(x): 0.97, D(G(z)): 0.11
# Epoch [11/300], Step [400/600], d_loss: 0.2045, g_loss: 5.1333, D(x): 0.97, D(G(z)): 0.10
# Epoch [11/300], Step [600/600], d_loss: 0.1863, g_loss: 5.6716, D(x): 0.95, D(G(z)): 0.03
# Saving fake_images-0012.png
# Epoch [12/300], Step [200/600], d_loss: 0.1779, g_loss: 5.7550, D(x): 0.91, D(G(z)): 0.00
# Epoch [12/300], Step [400/600], d_loss: 0.1209, g_loss: 7.1265, D(x): 0.96, D(G(z)): 0.02
# Epoch [12/300], Step [600/600], d_loss: 0.1683, g_loss: 4.4753, D(x): 0.96, D(G(z)): 0.08
# Saving fake_images-0013.png
# Epoch [13/300], Step [200/600], d_loss: 0.1126, g_loss: 3.9474, D(x): 0.97, D(G(z)): 0.05
# Epoch [13/300], Step [400/600], d_loss: 0.0698, g_loss: 5.1443, D(x): 0.99, D(G(z)): 0.04
# Epoch [13/300], Step [600/600], d_loss: 0.1797, g_loss: 4.8212, D(x): 0.93, D(G(z)): 0.04
# Saving fake_images-0014.png
# Epoch [14/300], Step [200/600], d_loss: 0.0941, g_loss: 4.3874, D(x): 0.98, D(G(z)): 0.05
# Epoch [14/300], Step [400/600], d_loss: 0.1728, g_loss: 5.5924, D(x): 0.97, D(G(z)): 0.07
# Epoch [14/300], Step [600/600], d_loss: 0.2831, g_loss: 5.7144, D(x): 0.91, D(G(z)): 0.02
# Saving fake_images-0015.png
# Epoch [15/300], Step [200/600], d_loss: 0.2163, g_loss: 4.9419, D(x): 0.92, D(G(z)): 0.06
# Epoch [15/300], Step [400/600], d_loss: 0.2337, g_loss: 6.4971, D(x): 0.94, D(G(z)): 0.07
# Epoch [15/300], Step [600/600], d_loss: 0.2392, g_loss: 4.4974, D(x): 0.97, D(G(z)): 0.15
# Saving fake_images-0016.png
# Epoch [16/300], Step [200/600], d_loss: 0.2298, g_loss: 4.3976, D(x): 0.91, D(G(z)): 0.03
# Epoch [16/300], Step [400/600], d_loss: 0.2519, g_loss: 4.4903, D(x): 0.97, D(G(z)): 0.15
# Epoch [16/300], Step [600/600], d_loss: 0.2618, g_loss: 5.1420, D(x): 0.94, D(G(z)): 0.12
# Saving fake_images-0017.png
# Epoch [17/300], Step [200/600], d_loss: 0.4720, g_loss: 6.3710, D(x): 0.84, D(G(z)): 0.01
# Epoch [17/300], Step [400/600], d_loss: 0.2484, g_loss: 3.0773, D(x): 0.95, D(G(z)): 0.09
# Epoch [17/300], Step [600/600], d_loss: 0.1816, g_loss: 3.7460, D(x): 0.98, D(G(z)): 0.11
# Saving fake_images-0018.png
# Epoch [18/300], Step [200/600], d_loss: 0.1691, g_loss: 6.0616, D(x): 0.98, D(G(z)): 0.10
# Epoch [18/300], Step [400/600], d_loss: 0.2036, g_loss: 4.7882, D(x): 0.95, D(G(z)): 0.10
# Epoch [18/300], Step [600/600], d_loss: 0.2639, g_loss: 5.4390, D(x): 0.93, D(G(z)): 0.04
# Saving fake_images-0019.png
# Epoch [19/300], Step [200/600], d_loss: 0.2172, g_loss: 5.1309, D(x): 0.97, D(G(z)): 0.11
# Epoch [19/300], Step [400/600], d_loss: 0.2622, g_loss: 4.6308, D(x): 0.96, D(G(z)): 0.10
# Epoch [19/300], Step [600/600], d_loss: 0.2610, g_loss: 4.1349, D(x): 0.91, D(G(z)): 0.06
# Saving fake_images-0020.png
# Epoch [20/300], Step [200/600], d_loss: 0.2106, g_loss: 4.5736, D(x): 0.96, D(G(z)): 0.08
# Epoch [20/300], Step [400/600], d_loss: 0.0984, g_loss: 3.5645, D(x): 0.98, D(G(z)): 0.05
# Epoch [20/300], Step [600/600], d_loss: 0.1888, g_loss: 4.6524, D(x): 0.92, D(G(z)): 0.04
# Saving fake_images-0021.png
# Epoch [21/300], Step [200/600], d_loss: 0.1761, g_loss: 2.4411, D(x): 0.93, D(G(z)): 0.03
# Epoch [21/300], Step [400/600], d_loss: 0.2629, g_loss: 4.4212, D(x): 0.92, D(G(z)): 0.10
# Epoch [21/300], Step [600/600], d_loss: 0.2394, g_loss: 3.2811, D(x): 0.95, D(G(z)): 0.12
# Saving fake_images-0022.png
# Epoch [22/300], Step [200/600], d_loss: 0.3206, g_loss: 4.6761, D(x): 0.92, D(G(z)): 0.10
# Epoch [22/300], Step [400/600], d_loss: 0.2316, g_loss: 5.0505, D(x): 0.92, D(G(z)): 0.06
# Epoch [22/300], Step [600/600], d_loss: 0.2820, g_loss: 3.5202, D(x): 0.95, D(G(z)): 0.11
# Saving fake_images-0023.png
# Epoch [23/300], Step [200/600], d_loss: 0.2888, g_loss: 3.3987, D(x): 0.93, D(G(z)): 0.14
# Epoch [23/300], Step [400/600], d_loss: 0.3061, g_loss: 5.0072, D(x): 0.91, D(G(z)): 0.10
# Epoch [23/300], Step [600/600], d_loss: 0.2665, g_loss: 4.4322, D(x): 0.90, D(G(z)): 0.04
# Saving fake_images-0024.png
# Epoch [24/300], Step [200/600], d_loss: 0.4835, g_loss: 3.9006, D(x): 0.88, D(G(z)): 0.13
# Epoch [24/300], Step [400/600], d_loss: 0.2024, g_loss: 4.1754, D(x): 0.93, D(G(z)): 0.08
# Epoch [24/300], Step [600/600], d_loss: 0.3220, g_loss: 4.2238, D(x): 0.91, D(G(z)): 0.07
# Saving fake_images-0025.png
# Epoch [25/300], Step [200/600], d_loss: 0.2729, g_loss: 4.3555, D(x): 0.90, D(G(z)): 0.04
# Epoch [25/300], Step [400/600], d_loss: 0.2896, g_loss: 4.0005, D(x): 0.90, D(G(z)): 0.08
# Epoch [25/300], Step [600/600], d_loss: 0.2596, g_loss: 3.4397, D(x): 0.93, D(G(z)): 0.11
# Saving fake_images-0026.png
# Epoch [26/300], Step [200/600], d_loss: 0.2306, g_loss: 3.5038, D(x): 0.94, D(G(z)): 0.11
# Epoch [26/300], Step [400/600], d_loss: 0.2565, g_loss: 4.0643, D(x): 0.92, D(G(z)): 0.09
# Epoch [26/300], Step [600/600], d_loss: 0.2728, g_loss: 3.9297, D(x): 0.91, D(G(z)): 0.06
# Saving fake_images-0027.png
# Epoch [27/300], Step [200/600], d_loss: 0.5976, g_loss: 4.2693, D(x): 0.83, D(G(z)): 0.13
# Epoch [27/300], Step [400/600], d_loss: 0.2650, g_loss: 4.1941, D(x): 0.95, D(G(z)): 0.12
# Epoch [27/300], Step [600/600], d_loss: 0.3759, g_loss: 4.1372, D(x): 0.89, D(G(z)): 0.13
# Saving fake_images-0028.png
# Epoch [28/300], Step [200/600], d_loss: 0.5929, g_loss: 3.8683, D(x): 0.81, D(G(z)): 0.11
# Epoch [28/300], Step [400/600], d_loss: 0.2961, g_loss: 3.4709, D(x): 0.92, D(G(z)): 0.12
# Epoch [28/300], Step [600/600], d_loss: 0.2909, g_loss: 3.6228, D(x): 0.92, D(G(z)): 0.11
# Saving fake_images-0029.png
# Epoch [29/300], Step [200/600], d_loss: 0.3961, g_loss: 4.0612, D(x): 0.85, D(G(z)): 0.06
# Epoch [29/300], Step [400/600], d_loss: 0.7260, g_loss: 4.5097, D(x): 0.76, D(G(z)): 0.06
# Epoch [29/300], Step [600/600], d_loss: 0.4638, g_loss: 3.3886, D(x): 0.86, D(G(z)): 0.16
# Saving fake_images-0030.png
# Epoch [30/300], Step [200/600], d_loss: 0.5112, g_loss: 3.0967, D(x): 0.92, D(G(z)): 0.23
# Epoch [30/300], Step [400/600], d_loss: 0.4524, g_loss: 2.4325, D(x): 0.88, D(G(z)): 0.17
# Epoch [30/300], Step [600/600], d_loss: 0.5014, g_loss: 2.9937, D(x): 0.84, D(G(z)): 0.12
# Saving fake_images-0031.png
# Epoch [31/300], Step [200/600], d_loss: 0.5117, g_loss: 2.9868, D(x): 0.90, D(G(z)): 0.20
# Epoch [31/300], Step [400/600], d_loss: 0.4764, g_loss: 3.3038, D(x): 0.91, D(G(z)): 0.19
# Epoch [31/300], Step [600/600], d_loss: 0.3873, g_loss: 3.0170, D(x): 0.87, D(G(z)): 0.13
# Saving fake_images-0032.png
# Epoch [32/300], Step [200/600], d_loss: 0.5431, g_loss: 2.6011, D(x): 0.84, D(G(z)): 0.15
# Epoch [32/300], Step [400/600], d_loss: 0.3328, g_loss: 3.3117, D(x): 0.89, D(G(z)): 0.09
# Epoch [32/300], Step [600/600], d_loss: 0.3016, g_loss: 4.8553, D(x): 0.91, D(G(z)): 0.11
# Saving fake_images-0033.png
# Epoch [33/300], Step [200/600], d_loss: 0.5032, g_loss: 4.5159, D(x): 0.84, D(G(z)): 0.08
# Epoch [33/300], Step [400/600], d_loss: 0.2836, g_loss: 4.9989, D(x): 0.93, D(G(z)): 0.10
# Epoch [33/300], Step [600/600], d_loss: 0.2391, g_loss: 4.5581, D(x): 0.92, D(G(z)): 0.10
# Saving fake_images-0034.png
# Epoch [34/300], Step [200/600], d_loss: 0.3119, g_loss: 4.2439, D(x): 0.91, D(G(z)): 0.11
# Epoch [34/300], Step [400/600], d_loss: 0.4961, g_loss: 2.8174, D(x): 0.89, D(G(z)): 0.22
# Epoch [34/300], Step [600/600], d_loss: 0.4955, g_loss: 3.3474, D(x): 0.83, D(G(z)): 0.04
# Saving fake_images-0035.png
# Epoch [35/300], Step [200/600], d_loss: 0.4678, g_loss: 2.9030, D(x): 0.86, D(G(z)): 0.12
# Epoch [35/300], Step [400/600], d_loss: 0.3912, g_loss: 3.1826, D(x): 0.88, D(G(z)): 0.11
# Epoch [35/300], Step [600/600], d_loss: 0.4150, g_loss: 3.3043, D(x): 0.87, D(G(z)): 0.08
# Saving fake_images-0036.png
# Epoch [36/300], Step [200/600], d_loss: 0.4126, g_loss: 3.5181, D(x): 0.90, D(G(z)): 0.16
# Epoch [36/300], Step [400/600], d_loss: 0.4366, g_loss: 3.0509, D(x): 0.84, D(G(z)): 0.09
# Epoch [36/300], Step [600/600], d_loss: 0.3107, g_loss: 3.5843, D(x): 0.92, D(G(z)): 0.13
# Saving fake_images-0037.png
# Epoch [37/300], Step [200/600], d_loss: 0.4961, g_loss: 3.0417, D(x): 0.89, D(G(z)): 0.19
# Epoch [37/300], Step [400/600], d_loss: 0.4931, g_loss: 2.7451, D(x): 0.84, D(G(z)): 0.15
# Epoch [37/300], Step [600/600], d_loss: 0.5930, g_loss: 3.7147, D(x): 0.83, D(G(z)): 0.17
# Saving fake_images-0038.png
# Epoch [38/300], Step [200/600], d_loss: 0.4209, g_loss: 2.5095, D(x): 0.85, D(G(z)): 0.12
# Epoch [38/300], Step [400/600], d_loss: 0.4964, g_loss: 2.8524, D(x): 0.89, D(G(z)): 0.21
# Epoch [38/300], Step [600/600], d_loss: 0.5376, g_loss: 2.9545, D(x): 0.87, D(G(z)): 0.17
# Saving fake_images-0039.png
# Epoch [39/300], Step [200/600], d_loss: 0.5266, g_loss: 2.6112, D(x): 0.81, D(G(z)): 0.13
# Epoch [39/300], Step [400/600], d_loss: 0.6504, g_loss: 2.8150, D(x): 0.78, D(G(z)): 0.19
# Epoch [39/300], Step [600/600], d_loss: 0.7126, g_loss: 3.0575, D(x): 0.81, D(G(z)): 0.17
# Saving fake_images-0040.png
# Epoch [40/300], Step [200/600], d_loss: 0.6327, g_loss: 2.8113, D(x): 0.75, D(G(z)): 0.09
# Epoch [40/300], Step [400/600], d_loss: 0.4978, g_loss: 3.1257, D(x): 0.87, D(G(z)): 0.20
# Epoch [40/300], Step [600/600], d_loss: 0.3104, g_loss: 3.7841, D(x): 0.88, D(G(z)): 0.09
# Saving fake_images-0041.png
# Epoch [41/300], Step [200/600], d_loss: 0.4565, g_loss: 2.5665, D(x): 0.86, D(G(z)): 0.16
# Epoch [41/300], Step [400/600], d_loss: 0.7166, g_loss: 2.6925, D(x): 0.76, D(G(z)): 0.15
# Epoch [41/300], Step [600/600], d_loss: 0.4122, g_loss: 3.4447, D(x): 0.86, D(G(z)): 0.14
# Saving fake_images-0042.png
# Epoch [42/300], Step [200/600], d_loss: 0.4760, g_loss: 2.3872, D(x): 0.83, D(G(z)): 0.12
# Epoch [42/300], Step [400/600], d_loss: 0.5488, g_loss: 3.1883, D(x): 0.85, D(G(z)): 0.16
# Epoch [42/300], Step [600/600], d_loss: 0.3532, g_loss: 3.6190, D(x): 0.85, D(G(z)): 0.07
# Saving fake_images-0043.png
# Epoch [43/300], Step [200/600], d_loss: 0.5201, g_loss: 2.9581, D(x): 0.82, D(G(z)): 0.14
# Epoch [43/300], Step [400/600], d_loss: 0.6545, g_loss: 3.3521, D(x): 0.77, D(G(z)): 0.08
# Epoch [43/300], Step [600/600], d_loss: 0.3363, g_loss: 3.4334, D(x): 0.92, D(G(z)): 0.15
# Saving fake_images-0044.png
# Epoch [44/300], Step [200/600], d_loss: 0.4422, g_loss: 4.2183, D(x): 0.81, D(G(z)): 0.07
# Epoch [44/300], Step [400/600], d_loss: 0.3602, g_loss: 3.3399, D(x): 0.90, D(G(z)): 0.17
# Epoch [44/300], Step [600/600], d_loss: 0.4925, g_loss: 3.1514, D(x): 0.85, D(G(z)): 0.16
# Saving fake_images-0045.png
# Epoch [45/300], Step [200/600], d_loss: 0.3947, g_loss: 3.9725, D(x): 0.84, D(G(z)): 0.10
# Epoch [45/300], Step [400/600], d_loss: 0.6830, g_loss: 2.9276, D(x): 0.76, D(G(z)): 0.15
# Epoch [45/300], Step [600/600], d_loss: 0.6844, g_loss: 1.7706, D(x): 0.84, D(G(z)): 0.19
# Saving fake_images-0046.png
# Epoch [46/300], Step [200/600], d_loss: 0.4839, g_loss: 2.7238, D(x): 0.83, D(G(z)): 0.12
# Epoch [46/300], Step [400/600], d_loss: 0.7638, g_loss: 2.4266, D(x): 0.76, D(G(z)): 0.19
# Epoch [46/300], Step [600/600], d_loss: 0.5138, g_loss: 3.1359, D(x): 0.78, D(G(z)): 0.09
# Saving fake_images-0047.png
# Epoch [47/300], Step [200/600], d_loss: 0.7713, g_loss: 1.8552, D(x): 0.75, D(G(z)): 0.16
# Epoch [47/300], Step [400/600], d_loss: 0.7955, g_loss: 2.6534, D(x): 0.71, D(G(z)): 0.12
# Epoch [47/300], Step [600/600], d_loss: 0.6726, g_loss: 2.4991, D(x): 0.80, D(G(z)): 0.21
# Saving fake_images-0048.png
# Epoch [48/300], Step [200/600], d_loss: 0.6145, g_loss: 3.6140, D(x): 0.77, D(G(z)): 0.12
# Epoch [48/300], Step [400/600], d_loss: 0.6174, g_loss: 2.5915, D(x): 0.88, D(G(z)): 0.28
# Epoch [48/300], Step [600/600], d_loss: 0.8044, g_loss: 2.0097, D(x): 0.72, D(G(z)): 0.21
# Saving fake_images-0049.png
# Epoch [49/300], Step [200/600], d_loss: 0.6918, g_loss: 2.5273, D(x): 0.85, D(G(z)): 0.29
# Epoch [49/300], Step [400/600], d_loss: 0.5707, g_loss: 2.7198, D(x): 0.81, D(G(z)): 0.16
# Epoch [49/300], Step [600/600], d_loss: 0.4522, g_loss: 2.9233, D(x): 0.82, D(G(z)): 0.12
# Saving fake_images-0050.png
# Epoch [50/300], Step [200/600], d_loss: 0.6509, g_loss: 2.8142, D(x): 0.81, D(G(z)): 0.18
# Epoch [50/300], Step [400/600], d_loss: 0.6524, g_loss: 2.6649, D(x): 0.73, D(G(z)): 0.12
# Epoch [50/300], Step [600/600], d_loss: 0.7626, g_loss: 2.5940, D(x): 0.75, D(G(z)): 0.19
# Saving fake_images-0051.png
# Epoch [51/300], Step [200/600], d_loss: 0.6866, g_loss: 1.8852, D(x): 0.79, D(G(z)): 0.21
# Epoch [51/300], Step [400/600], d_loss: 0.7538, g_loss: 2.6182, D(x): 0.74, D(G(z)): 0.17
# Epoch [51/300], Step [600/600], d_loss: 0.6346, g_loss: 2.1396, D(x): 0.83, D(G(z)): 0.26
# Saving fake_images-0052.png
# Epoch [52/300], Step [200/600], d_loss: 0.6756, g_loss: 2.4633, D(x): 0.81, D(G(z)): 0.24
# Epoch [52/300], Step [400/600], d_loss: 0.3987, g_loss: 3.2429, D(x): 0.83, D(G(z)): 0.09
# Epoch [52/300], Step [600/600], d_loss: 0.8670, g_loss: 2.9734, D(x): 0.67, D(G(z)): 0.12
# Saving fake_images-0053.png
# Epoch [53/300], Step [200/600], d_loss: 0.5851, g_loss: 2.0545, D(x): 0.81, D(G(z)): 0.20
# Epoch [53/300], Step [400/600], d_loss: 0.3717, g_loss: 2.5825, D(x): 0.84, D(G(z)): 0.11
# Epoch [53/300], Step [600/600], d_loss: 0.4196, g_loss: 2.5679, D(x): 0.86, D(G(z)): 0.17
# Saving fake_images-0054.png
# Epoch [54/300], Step [200/600], d_loss: 0.5104, g_loss: 2.7598, D(x): 0.83, D(G(z)): 0.18
# Epoch [54/300], Step [400/600], d_loss: 0.5900, g_loss: 2.9919, D(x): 0.83, D(G(z)): 0.19
# Epoch [54/300], Step [600/600], d_loss: 0.8283, g_loss: 2.3491, D(x): 0.71, D(G(z)): 0.14
# Saving fake_images-0055.png
# Epoch [55/300], Step [200/600], d_loss: 0.7596, g_loss: 2.3315, D(x): 0.79, D(G(z)): 0.26
# Epoch [55/300], Step [400/600], d_loss: 0.7875, g_loss: 2.4955, D(x): 0.77, D(G(z)): 0.23
# Epoch [55/300], Step [600/600], d_loss: 0.7016, g_loss: 2.2603, D(x): 0.79, D(G(z)): 0.22
# Saving fake_images-0056.png
# Epoch [56/300], Step [200/600], d_loss: 0.8138, g_loss: 1.7312, D(x): 0.73, D(G(z)): 0.19
# Epoch [56/300], Step [400/600], d_loss: 0.8191, g_loss: 2.4317, D(x): 0.80, D(G(z)): 0.26
# Epoch [56/300], Step [600/600], d_loss: 0.8179, g_loss: 2.1845, D(x): 0.76, D(G(z)): 0.24
# Saving fake_images-0057.png
# Epoch [57/300], Step [200/600], d_loss: 0.6353, g_loss: 3.1289, D(x): 0.78, D(G(z)): 0.18
# Epoch [57/300], Step [400/600], d_loss: 0.7979, g_loss: 2.1114, D(x): 0.76, D(G(z)): 0.26
# Epoch [57/300], Step [600/600], d_loss: 0.5772, g_loss: 2.3080, D(x): 0.82, D(G(z)): 0.21
# Saving fake_images-0058.png
# Epoch [58/300], Step [200/600], d_loss: 0.7117, g_loss: 1.8923, D(x): 0.76, D(G(z)): 0.21
# Epoch [58/300], Step [400/600], d_loss: 0.7432, g_loss: 1.8574, D(x): 0.80, D(G(z)): 0.27
# Epoch [58/300], Step [600/600], d_loss: 0.5804, g_loss: 2.0916, D(x): 0.84, D(G(z)): 0.23
# Saving fake_images-0059.png
# Epoch [59/300], Step [200/600], d_loss: 0.5026, g_loss: 2.3429, D(x): 0.80, D(G(z)): 0.18
# Epoch [59/300], Step [400/600], d_loss: 0.7607, g_loss: 1.6654, D(x): 0.81, D(G(z)): 0.31
# Epoch [59/300], Step [600/600], d_loss: 0.5954, g_loss: 1.9864, D(x): 0.84, D(G(z)): 0.24
# Saving fake_images-0060.png
# Epoch [60/300], Step [200/600], d_loss: 0.6912, g_loss: 2.1621, D(x): 0.80, D(G(z)): 0.24
# Epoch [60/300], Step [400/600], d_loss: 0.7388, g_loss: 1.8929, D(x): 0.78, D(G(z)): 0.21
# Epoch [60/300], Step [600/600], d_loss: 0.5923, g_loss: 2.9159, D(x): 0.75, D(G(z)): 0.14
# Saving fake_images-0061.png
# Epoch [61/300], Step [200/600], d_loss: 0.7114, g_loss: 2.3739, D(x): 0.77, D(G(z)): 0.25
# Epoch [61/300], Step [400/600], d_loss: 0.6377, g_loss: 2.0065, D(x): 0.76, D(G(z)): 0.19
# Epoch [61/300], Step [600/600], d_loss: 0.5826, g_loss: 1.9722, D(x): 0.85, D(G(z)): 0.24
# Saving fake_images-0062.png
# Epoch [62/300], Step [200/600], d_loss: 0.8760, g_loss: 2.3643, D(x): 0.68, D(G(z)): 0.20
# Epoch [62/300], Step [400/600], d_loss: 0.5995, g_loss: 1.9926, D(x): 0.83, D(G(z)): 0.23
# Epoch [62/300], Step [600/600], d_loss: 0.6904, g_loss: 2.2955, D(x): 0.77, D(G(z)): 0.21
# Saving fake_images-0063.png
# Epoch [63/300], Step [200/600], d_loss: 0.6182, g_loss: 2.4524, D(x): 0.76, D(G(z)): 0.17
# Epoch [63/300], Step [400/600], d_loss: 0.5246, g_loss: 2.1459, D(x): 0.78, D(G(z)): 0.15
# Epoch [63/300], Step [600/600], d_loss: 0.7860, g_loss: 2.5603, D(x): 0.70, D(G(z)): 0.19
# Saving fake_images-0064.png
# Epoch [64/300], Step [200/600], d_loss: 0.6198, g_loss: 3.0439, D(x): 0.76, D(G(z)): 0.17
# Epoch [64/300], Step [400/600], d_loss: 0.9781, g_loss: 2.1964, D(x): 0.83, D(G(z)): 0.40
# Epoch [64/300], Step [600/600], d_loss: 0.6679, g_loss: 2.3882, D(x): 0.73, D(G(z)): 0.16
# Saving fake_images-0065.png
# Epoch [65/300], Step [200/600], d_loss: 0.6100, g_loss: 2.3549, D(x): 0.86, D(G(z)): 0.26
# Epoch [65/300], Step [400/600], d_loss: 0.7341, g_loss: 2.4598, D(x): 0.74, D(G(z)): 0.19
# Epoch [65/300], Step [600/600], d_loss: 0.7514, g_loss: 1.9614, D(x): 0.80, D(G(z)): 0.29
# Saving fake_images-0066.png
# Epoch [66/300], Step [200/600], d_loss: 0.8290, g_loss: 2.6860, D(x): 0.66, D(G(z)): 0.11
# Epoch [66/300], Step [400/600], d_loss: 0.8388, g_loss: 1.6776, D(x): 0.76, D(G(z)): 0.28
# Epoch [66/300], Step [600/600], d_loss: 0.6555, g_loss: 2.7022, D(x): 0.79, D(G(z)): 0.22
# Saving fake_images-0067.png
# Epoch [67/300], Step [200/600], d_loss: 0.6695, g_loss: 2.0398, D(x): 0.77, D(G(z)): 0.20
# Epoch [67/300], Step [400/600], d_loss: 0.7071, g_loss: 1.8186, D(x): 0.84, D(G(z)): 0.29
# Epoch [67/300], Step [600/600], d_loss: 0.8414, g_loss: 2.5869, D(x): 0.67, D(G(z)): 0.14
# Saving fake_images-0068.png
# Epoch [68/300], Step [200/600], d_loss: 0.6242, g_loss: 2.3382, D(x): 0.80, D(G(z)): 0.21
# Epoch [68/300], Step [400/600], d_loss: 0.4971, g_loss: 2.7931, D(x): 0.78, D(G(z)): 0.15
# Epoch [68/300], Step [600/600], d_loss: 0.7363, g_loss: 2.1557, D(x): 0.70, D(G(z)): 0.16
# Saving fake_images-0069.png
# Epoch [69/300], Step [200/600], d_loss: 0.7698, g_loss: 2.0616, D(x): 0.77, D(G(z)): 0.25
# Epoch [69/300], Step [400/600], d_loss: 0.6720, g_loss: 2.0007, D(x): 0.77, D(G(z)): 0.21
# Epoch [69/300], Step [600/600], d_loss: 0.7845, g_loss: 2.1837, D(x): 0.69, D(G(z)): 0.17
# Saving fake_images-0070.png
# Epoch [70/300], Step [200/600], d_loss: 0.8014, g_loss: 1.6437, D(x): 0.79, D(G(z)): 0.26
# Epoch [70/300], Step [400/600], d_loss: 0.5651, g_loss: 2.5164, D(x): 0.85, D(G(z)): 0.23
# Epoch [70/300], Step [600/600], d_loss: 0.5280, g_loss: 2.0360, D(x): 0.85, D(G(z)): 0.22
# Saving fake_images-0071.png
# Epoch [71/300], Step [200/600], d_loss: 0.7537, g_loss: 2.2722, D(x): 0.73, D(G(z)): 0.18
# Epoch [71/300], Step [400/600], d_loss: 0.5646, g_loss: 2.6800, D(x): 0.81, D(G(z)): 0.17
# Epoch [71/300], Step [600/600], d_loss: 0.6977, g_loss: 2.6842, D(x): 0.75, D(G(z)): 0.20
# Saving fake_images-0072.png
# Epoch [72/300], Step [200/600], d_loss: 0.7590, g_loss: 2.7916, D(x): 0.74, D(G(z)): 0.19
# Epoch [72/300], Step [400/600], d_loss: 0.6409, g_loss: 1.6211, D(x): 0.84, D(G(z)): 0.29
# Epoch [72/300], Step [600/600], d_loss: 0.7213, g_loss: 2.4559, D(x): 0.76, D(G(z)): 0.22
# Saving fake_images-0073.png
# Epoch [73/300], Step [200/600], d_loss: 0.6818, g_loss: 2.0316, D(x): 0.82, D(G(z)): 0.25
# Epoch [73/300], Step [400/600], d_loss: 0.6868, g_loss: 1.8650, D(x): 0.78, D(G(z)): 0.23
# Epoch [73/300], Step [600/600], d_loss: 0.6076, g_loss: 2.0640, D(x): 0.79, D(G(z)): 0.22
# Saving fake_images-0074.png
# Epoch [74/300], Step [200/600], d_loss: 0.9091, g_loss: 1.7711, D(x): 0.78, D(G(z)): 0.35
# Epoch [74/300], Step [400/600], d_loss: 0.7558, g_loss: 2.4232, D(x): 0.78, D(G(z)): 0.27
# Epoch [74/300], Step [600/600], d_loss: 0.7530, g_loss: 2.5224, D(x): 0.76, D(G(z)): 0.25
# Saving fake_images-0075.png
# Epoch [75/300], Step [200/600], d_loss: 0.6646, g_loss: 2.2750, D(x): 0.73, D(G(z)): 0.14
# Epoch [75/300], Step [400/600], d_loss: 0.6994, g_loss: 2.3407, D(x): 0.74, D(G(z)): 0.19
# Epoch [75/300], Step [600/600], d_loss: 0.6721, g_loss: 2.1907, D(x): 0.82, D(G(z)): 0.28
# Saving fake_images-0076.png
# Epoch [76/300], Step [200/600], d_loss: 0.6861, g_loss: 1.6783, D(x): 0.77, D(G(z)): 0.22
# Epoch [76/300], Step [400/600], d_loss: 0.5754, g_loss: 1.7950, D(x): 0.86, D(G(z)): 0.24
# Epoch [76/300], Step [600/600], d_loss: 0.5464, g_loss: 2.3244, D(x): 0.81, D(G(z)): 0.19
# Saving fake_images-0077.png
# Epoch [77/300], Step [200/600], d_loss: 0.7318, g_loss: 2.0552, D(x): 0.78, D(G(z)): 0.24
# Epoch [77/300], Step [400/600], d_loss: 0.6097, g_loss: 2.2255, D(x): 0.78, D(G(z)): 0.18
# Epoch [77/300], Step [600/600], d_loss: 0.8173, g_loss: 1.6647, D(x): 0.72, D(G(z)): 0.22
# Saving fake_images-0078.png
# Epoch [78/300], Step [200/600], d_loss: 0.6581, g_loss: 2.7066, D(x): 0.75, D(G(z)): 0.20
# Epoch [78/300], Step [400/600], d_loss: 0.7925, g_loss: 1.6867, D(x): 0.79, D(G(z)): 0.29
# Epoch [78/300], Step [600/600], d_loss: 0.9254, g_loss: 1.8818, D(x): 0.68, D(G(z)): 0.22
# Saving fake_images-0079.png
# Epoch [79/300], Step [200/600], d_loss: 0.6117, g_loss: 2.4162, D(x): 0.80, D(G(z)): 0.21
# Epoch [79/300], Step [400/600], d_loss: 0.9890, g_loss: 2.0069, D(x): 0.69, D(G(z)): 0.27
# Epoch [79/300], Step [600/600], d_loss: 0.7285, g_loss: 2.1322, D(x): 0.72, D(G(z)): 0.17
# Saving fake_images-0080.png
# Epoch [80/300], Step [200/600], d_loss: 0.6057, g_loss: 1.9901, D(x): 0.81, D(G(z)): 0.24
# Epoch [80/300], Step [400/600], d_loss: 0.8058, g_loss: 1.6241, D(x): 0.78, D(G(z)): 0.27
# Epoch [80/300], Step [600/600], d_loss: 0.9037, g_loss: 1.5328, D(x): 0.75, D(G(z)): 0.30
# Saving fake_images-0081.png
# Epoch [81/300], Step [200/600], d_loss: 0.7406, g_loss: 2.2722, D(x): 0.81, D(G(z)): 0.31
# Epoch [81/300], Step [400/600], d_loss: 0.7559, g_loss: 2.5590, D(x): 0.73, D(G(z)): 0.21
# Epoch [81/300], Step [600/600], d_loss: 0.8046, g_loss: 1.7459, D(x): 0.74, D(G(z)): 0.25
# Saving fake_images-0082.png
# Epoch [82/300], Step [200/600], d_loss: 0.7309, g_loss: 1.6604, D(x): 0.79, D(G(z)): 0.30
# Epoch [82/300], Step [400/600], d_loss: 0.7013, g_loss: 2.0559, D(x): 0.78, D(G(z)): 0.27
# Epoch [82/300], Step [600/600], d_loss: 0.5954, g_loss: 1.9898, D(x): 0.83, D(G(z)): 0.27
# Saving fake_images-0083.png
# Epoch [83/300], Step [200/600], d_loss: 0.6502, g_loss: 2.3379, D(x): 0.76, D(G(z)): 0.18
# Epoch [83/300], Step [400/600], d_loss: 0.6195, g_loss: 2.1325, D(x): 0.84, D(G(z)): 0.26
# Epoch [83/300], Step [600/600], d_loss: 0.6888, g_loss: 2.8584, D(x): 0.75, D(G(z)): 0.19
# Saving fake_images-0084.png
# Epoch [84/300], Step [200/600], d_loss: 0.6548, g_loss: 2.1239, D(x): 0.77, D(G(z)): 0.19
# Epoch [84/300], Step [400/600], d_loss: 0.8663, g_loss: 2.7232, D(x): 0.64, D(G(z)): 0.12
# Epoch [84/300], Step [600/600], d_loss: 0.8682, g_loss: 1.7771, D(x): 0.71, D(G(z)): 0.22
# Saving fake_images-0085.png
# Epoch [85/300], Step [200/600], d_loss: 0.7270, g_loss: 2.2713, D(x): 0.84, D(G(z)): 0.31
# Epoch [85/300], Step [400/600], d_loss: 0.7982, g_loss: 1.9381, D(x): 0.70, D(G(z)): 0.20
# Epoch [85/300], Step [600/600], d_loss: 0.8774, g_loss: 1.8198, D(x): 0.72, D(G(z)): 0.29
# Saving fake_images-0086.png
# Epoch [86/300], Step [200/600], d_loss: 0.7383, g_loss: 1.6904, D(x): 0.76, D(G(z)): 0.25
# Epoch [86/300], Step [400/600], d_loss: 0.8322, g_loss: 1.7857, D(x): 0.66, D(G(z)): 0.20
# Epoch [86/300], Step [600/600], d_loss: 0.8182, g_loss: 2.0980, D(x): 0.78, D(G(z)): 0.30
# Saving fake_images-0087.png
# Epoch [87/300], Step [200/600], d_loss: 0.6203, g_loss: 2.4480, D(x): 0.77, D(G(z)): 0.18
# Epoch [87/300], Step [400/600], d_loss: 0.7935, g_loss: 1.9237, D(x): 0.79, D(G(z)): 0.30
# Epoch [87/300], Step [600/600], d_loss: 0.8046, g_loss: 2.1644, D(x): 0.77, D(G(z)): 0.30
# Saving fake_images-0088.png
# Epoch [88/300], Step [200/600], d_loss: 0.8102, g_loss: 1.7034, D(x): 0.81, D(G(z)): 0.34
# Epoch [88/300], Step [400/600], d_loss: 0.8833, g_loss: 2.0266, D(x): 0.63, D(G(z)): 0.15
# Epoch [88/300], Step [600/600], d_loss: 0.8093, g_loss: 2.0148, D(x): 0.76, D(G(z)): 0.28
# Saving fake_images-0089.png
# Epoch [89/300], Step [200/600], d_loss: 0.7372, g_loss: 1.5439, D(x): 0.78, D(G(z)): 0.27
# Epoch [89/300], Step [400/600], d_loss: 0.6830, g_loss: 1.5818, D(x): 0.80, D(G(z)): 0.27
# Epoch [89/300], Step [600/600], d_loss: 0.5808, g_loss: 1.7627, D(x): 0.81, D(G(z)): 0.20
# Saving fake_images-0090.png
# Epoch [90/300], Step [200/600], d_loss: 0.7490, g_loss: 2.2583, D(x): 0.82, D(G(z)): 0.27
# Epoch [90/300], Step [400/600], d_loss: 0.8934, g_loss: 1.7574, D(x): 0.69, D(G(z)): 0.25
# Epoch [90/300], Step [600/600], d_loss: 0.7236, g_loss: 1.4487, D(x): 0.76, D(G(z)): 0.25
# Saving fake_images-0091.png
# Epoch [91/300], Step [200/600], d_loss: 0.7728, g_loss: 1.8340, D(x): 0.71, D(G(z)): 0.24
# Epoch [91/300], Step [400/600], d_loss: 0.9345, g_loss: 1.5909, D(x): 0.71, D(G(z)): 0.28
# Epoch [91/300], Step [600/600], d_loss: 0.8023, g_loss: 2.4507, D(x): 0.76, D(G(z)): 0.27
# Saving fake_images-0092.png
# Epoch [92/300], Step [200/600], d_loss: 0.7715, g_loss: 1.9558, D(x): 0.70, D(G(z)): 0.18
# Epoch [92/300], Step [400/600], d_loss: 0.6700, g_loss: 2.0496, D(x): 0.77, D(G(z)): 0.24
# Epoch [92/300], Step [600/600], d_loss: 0.6592, g_loss: 1.7563, D(x): 0.75, D(G(z)): 0.18
# Saving fake_images-0093.png
# Epoch [93/300], Step [200/600], d_loss: 0.5653, g_loss: 2.2901, D(x): 0.85, D(G(z)): 0.27
# Epoch [93/300], Step [400/600], d_loss: 0.8204, g_loss: 2.2678, D(x): 0.83, D(G(z)): 0.36
# Epoch [93/300], Step [600/600], d_loss: 0.9521, g_loss: 1.8880, D(x): 0.72, D(G(z)): 0.32
# Saving fake_images-0094.png
# Epoch [94/300], Step [200/600], d_loss: 0.7831, g_loss: 2.2912, D(x): 0.69, D(G(z)): 0.14
# Epoch [94/300], Step [400/600], d_loss: 0.6659, g_loss: 2.2871, D(x): 0.75, D(G(z)): 0.20
# Epoch [94/300], Step [600/600], d_loss: 0.9346, g_loss: 1.5211, D(x): 0.82, D(G(z)): 0.40
# Saving fake_images-0095.png
# Epoch [95/300], Step [200/600], d_loss: 0.8192, g_loss: 1.9687, D(x): 0.76, D(G(z)): 0.30
# Epoch [95/300], Step [400/600], d_loss: 0.7684, g_loss: 1.7573, D(x): 0.73, D(G(z)): 0.24
# Epoch [95/300], Step [600/600], d_loss: 0.7944, g_loss: 1.8764, D(x): 0.74, D(G(z)): 0.25
# Saving fake_images-0096.png
# Epoch [96/300], Step [200/600], d_loss: 0.7277, g_loss: 2.1995, D(x): 0.77, D(G(z)): 0.26
# Epoch [96/300], Step [400/600], d_loss: 0.9411, g_loss: 1.4669, D(x): 0.66, D(G(z)): 0.26
# Epoch [96/300], Step [600/600], d_loss: 0.9178, g_loss: 1.4759, D(x): 0.74, D(G(z)): 0.33
# Saving fake_images-0097.png
# Epoch [97/300], Step [200/600], d_loss: 0.7204, g_loss: 1.9102, D(x): 0.76, D(G(z)): 0.25
# Epoch [97/300], Step [400/600], d_loss: 0.8400, g_loss: 2.1939, D(x): 0.72, D(G(z)): 0.28
# Epoch [97/300], Step [600/600], d_loss: 0.6794, g_loss: 2.4241, D(x): 0.75, D(G(z)): 0.22
# Saving fake_images-0098.png
# Epoch [98/300], Step [200/600], d_loss: 0.8585, g_loss: 1.4865, D(x): 0.70, D(G(z)): 0.26
# Epoch [98/300], Step [400/600], d_loss: 0.7924, g_loss: 2.4867, D(x): 0.83, D(G(z)): 0.34
# Epoch [98/300], Step [600/600], d_loss: 0.9559, g_loss: 2.1408, D(x): 0.70, D(G(z)): 0.28
# Saving fake_images-0099.png
# Epoch [99/300], Step [200/600], d_loss: 0.5889, g_loss: 2.4596, D(x): 0.83, D(G(z)): 0.24
# Epoch [99/300], Step [400/600], d_loss: 0.8510, g_loss: 2.5065, D(x): 0.67, D(G(z)): 0.17
# Epoch [99/300], Step [600/600], d_loss: 0.7969, g_loss: 2.0015, D(x): 0.79, D(G(z)): 0.32
# Saving fake_images-0100.png
# Epoch [100/300], Step [200/600], d_loss: 0.7124, g_loss: 1.5093, D(x): 0.78, D(G(z)): 0.25
# Epoch [100/300], Step [400/600], d_loss: 0.9377, g_loss: 1.7019, D(x): 0.77, D(G(z)): 0.36
# Epoch [100/300], Step [600/600], d_loss: 0.6453, g_loss: 1.8329, D(x): 0.83, D(G(z)): 0.27
# Saving fake_images-0101.png
# Epoch [101/300], Step [200/600], d_loss: 0.6458, g_loss: 1.8208, D(x): 0.77, D(G(z)): 0.22
# Epoch [101/300], Step [400/600], d_loss: 0.6943, g_loss: 1.8547, D(x): 0.78, D(G(z)): 0.26
# Epoch [101/300], Step [600/600], d_loss: 0.9305, g_loss: 1.7904, D(x): 0.70, D(G(z)): 0.28
# Saving fake_images-0102.png
# Epoch [102/300], Step [200/600], d_loss: 0.9571, g_loss: 1.6719, D(x): 0.70, D(G(z)): 0.33
# Epoch [102/300], Step [400/600], d_loss: 1.1374, g_loss: 1.7859, D(x): 0.63, D(G(z)): 0.23
# Epoch [102/300], Step [600/600], d_loss: 1.0445, g_loss: 1.8087, D(x): 0.70, D(G(z)): 0.32
# Saving fake_images-0103.png
# Epoch [103/300], Step [200/600], d_loss: 0.6892, g_loss: 1.9793, D(x): 0.68, D(G(z)): 0.14
# Epoch [103/300], Step [400/600], d_loss: 1.1585, g_loss: 1.7151, D(x): 0.62, D(G(z)): 0.28
# Epoch [103/300], Step [600/600], d_loss: 0.8514, g_loss: 2.0842, D(x): 0.74, D(G(z)): 0.28
# Saving fake_images-0104.png
# Epoch [104/300], Step [200/600], d_loss: 1.0070, g_loss: 1.3303, D(x): 0.79, D(G(z)): 0.42
# Epoch [104/300], Step [400/600], d_loss: 0.9153, g_loss: 1.7366, D(x): 0.68, D(G(z)): 0.26
# Epoch [104/300], Step [600/600], d_loss: 0.5242, g_loss: 2.6849, D(x): 0.78, D(G(z)): 0.15
# Saving fake_images-0105.png
# Epoch [105/300], Step [200/600], d_loss: 0.9529, g_loss: 1.7864, D(x): 0.76, D(G(z)): 0.35
# Epoch [105/300], Step [400/600], d_loss: 0.8398, g_loss: 1.7392, D(x): 0.73, D(G(z)): 0.28
# Epoch [105/300], Step [600/600], d_loss: 0.7647, g_loss: 1.6217, D(x): 0.77, D(G(z)): 0.30
# Saving fake_images-0106.png
# Epoch [106/300], Step [200/600], d_loss: 0.7933, g_loss: 1.9068, D(x): 0.80, D(G(z)): 0.30
# Epoch [106/300], Step [400/600], d_loss: 0.8078, g_loss: 2.3439, D(x): 0.71, D(G(z)): 0.23
# Epoch [106/300], Step [600/600], d_loss: 0.8361, g_loss: 1.5231, D(x): 0.79, D(G(z)): 0.35
# Saving fake_images-0107.png
# Epoch [107/300], Step [200/600], d_loss: 0.8017, g_loss: 1.8522, D(x): 0.76, D(G(z)): 0.29
# Epoch [107/300], Step [400/600], d_loss: 0.8175, g_loss: 1.4250, D(x): 0.71, D(G(z)): 0.25
# Epoch [107/300], Step [600/600], d_loss: 0.9231, g_loss: 1.9551, D(x): 0.77, D(G(z)): 0.36
# Saving fake_images-0108.png
# Epoch [108/300], Step [200/600], d_loss: 0.9023, g_loss: 1.6985, D(x): 0.70, D(G(z)): 0.29
# Epoch [108/300], Step [400/600], d_loss: 1.0216, g_loss: 1.4470, D(x): 0.75, D(G(z)): 0.34
# Epoch [108/300], Step [600/600], d_loss: 1.1142, g_loss: 1.5808, D(x): 0.75, D(G(z)): 0.42
# Saving fake_images-0109.png
# Epoch [109/300], Step [200/600], d_loss: 0.7946, g_loss: 1.5084, D(x): 0.80, D(G(z)): 0.34
# Epoch [109/300], Step [400/600], d_loss: 1.0805, g_loss: 1.5041, D(x): 0.69, D(G(z)): 0.29
# Epoch [109/300], Step [600/600], d_loss: 1.0957, g_loss: 1.2754, D(x): 0.69, D(G(z)): 0.35
# Saving fake_images-0110.png
# Epoch [110/300], Step [200/600], d_loss: 0.8564, g_loss: 1.8327, D(x): 0.75, D(G(z)): 0.31
# Epoch [110/300], Step [400/600], d_loss: 0.9942, g_loss: 1.3163, D(x): 0.75, D(G(z)): 0.36
# Epoch [110/300], Step [600/600], d_loss: 1.1347, g_loss: 1.8114, D(x): 0.55, D(G(z)): 0.22
# Saving fake_images-0111.png
# Epoch [111/300], Step [200/600], d_loss: 0.8398, g_loss: 1.6014, D(x): 0.81, D(G(z)): 0.34
# Epoch [111/300], Step [400/600], d_loss: 0.7807, g_loss: 1.9291, D(x): 0.74, D(G(z)): 0.28
# Epoch [111/300], Step [600/600], d_loss: 0.8906, g_loss: 1.6734, D(x): 0.72, D(G(z)): 0.28
# Saving fake_images-0112.png
# Epoch [112/300], Step [200/600], d_loss: 0.8539, g_loss: 1.8348, D(x): 0.70, D(G(z)): 0.24
# Epoch [112/300], Step [400/600], d_loss: 0.7275, g_loss: 1.9884, D(x): 0.83, D(G(z)): 0.31
# Epoch [112/300], Step [600/600], d_loss: 1.0360, g_loss: 1.5700, D(x): 0.62, D(G(z)): 0.23
# Saving fake_images-0113.png
# Epoch [113/300], Step [200/600], d_loss: 0.9902, g_loss: 1.5101, D(x): 0.65, D(G(z)): 0.23
# Epoch [113/300], Step [400/600], d_loss: 0.5939, g_loss: 1.4325, D(x): 0.78, D(G(z)): 0.24
# Epoch [113/300], Step [600/600], d_loss: 0.8741, g_loss: 1.9046, D(x): 0.67, D(G(z)): 0.25
# Saving fake_images-0114.png
# Epoch [114/300], Step [200/600], d_loss: 0.9616, g_loss: 1.6813, D(x): 0.72, D(G(z)): 0.34
# Epoch [114/300], Step [400/600], d_loss: 0.9118, g_loss: 1.7374, D(x): 0.78, D(G(z)): 0.35
# Epoch [114/300], Step [600/600], d_loss: 0.8589, g_loss: 1.4227, D(x): 0.74, D(G(z)): 0.31
# Saving fake_images-0115.png
# Epoch [115/300], Step [200/600], d_loss: 1.1436, g_loss: 1.4163, D(x): 0.65, D(G(z)): 0.35
# Epoch [115/300], Step [400/600], d_loss: 0.9232, g_loss: 1.8274, D(x): 0.68, D(G(z)): 0.25
# Epoch [115/300], Step [600/600], d_loss: 0.9359, g_loss: 2.2047, D(x): 0.71, D(G(z)): 0.28
# Saving fake_images-0116.png
# Epoch [116/300], Step [200/600], d_loss: 1.1422, g_loss: 1.4035, D(x): 0.66, D(G(z)): 0.37
# Epoch [116/300], Step [400/600], d_loss: 0.8456, g_loss: 1.9287, D(x): 0.72, D(G(z)): 0.31
# Epoch [116/300], Step [600/600], d_loss: 0.9320, g_loss: 1.9847, D(x): 0.64, D(G(z)): 0.23
# Saving fake_images-0117.png
# Epoch [117/300], Step [200/600], d_loss: 0.9564, g_loss: 1.7076, D(x): 0.65, D(G(z)): 0.25
# Epoch [117/300], Step [400/600], d_loss: 0.9348, g_loss: 2.0531, D(x): 0.64, D(G(z)): 0.25
# Epoch [117/300], Step [600/600], d_loss: 0.8499, g_loss: 1.8699, D(x): 0.71, D(G(z)): 0.25
# Saving fake_images-0118.png
# Epoch [118/300], Step [200/600], d_loss: 0.7532, g_loss: 1.8839, D(x): 0.75, D(G(z)): 0.29
# Epoch [118/300], Step [400/600], d_loss: 0.9769, g_loss: 1.7629, D(x): 0.71, D(G(z)): 0.33
# Epoch [118/300], Step [600/600], d_loss: 0.9695, g_loss: 1.7620, D(x): 0.61, D(G(z)): 0.24
# Saving fake_images-0119.png
# Epoch [119/300], Step [200/600], d_loss: 0.8840, g_loss: 1.6828, D(x): 0.69, D(G(z)): 0.27
# Epoch [119/300], Step [400/600], d_loss: 1.2315, g_loss: 1.5444, D(x): 0.64, D(G(z)): 0.33
# Epoch [119/300], Step [600/600], d_loss: 0.9983, g_loss: 1.5466, D(x): 0.70, D(G(z)): 0.33
# Saving fake_images-0120.png
# Epoch [120/300], Step [200/600], d_loss: 0.8203, g_loss: 1.8788, D(x): 0.76, D(G(z)): 0.33
# Epoch [120/300], Step [400/600], d_loss: 0.9065, g_loss: 1.6397, D(x): 0.76, D(G(z)): 0.34
# Epoch [120/300], Step [600/600], d_loss: 0.9354, g_loss: 1.8333, D(x): 0.68, D(G(z)): 0.30
# Saving fake_images-0121.png
# Epoch [121/300], Step [200/600], d_loss: 0.9185, g_loss: 1.8685, D(x): 0.69, D(G(z)): 0.27
# Epoch [121/300], Step [400/600], d_loss: 0.9821, g_loss: 1.7627, D(x): 0.59, D(G(z)): 0.19
# Epoch [121/300], Step [600/600], d_loss: 0.9011, g_loss: 1.5807, D(x): 0.68, D(G(z)): 0.25
# Saving fake_images-0122.png
# Epoch [122/300], Step [200/600], d_loss: 0.8449, g_loss: 1.8439, D(x): 0.75, D(G(z)): 0.29
# Epoch [122/300], Step [400/600], d_loss: 0.8945, g_loss: 1.6433, D(x): 0.75, D(G(z)): 0.34
# Epoch [122/300], Step [600/600], d_loss: 0.6879, g_loss: 1.8529, D(x): 0.75, D(G(z)): 0.24
# Saving fake_images-0123.png
# Epoch [123/300], Step [200/600], d_loss: 0.8238, g_loss: 1.5973, D(x): 0.68, D(G(z)): 0.22
# Epoch [123/300], Step [400/600], d_loss: 0.8088, g_loss: 1.6823, D(x): 0.76, D(G(z)): 0.31
# Epoch [123/300], Step [600/600], d_loss: 0.9266, g_loss: 1.8430, D(x): 0.67, D(G(z)): 0.23
# Saving fake_images-0124.png
# Epoch [124/300], Step [200/600], d_loss: 0.7954, g_loss: 1.8967, D(x): 0.65, D(G(z)): 0.16
# Epoch [124/300], Step [400/600], d_loss: 0.9055, g_loss: 1.5792, D(x): 0.69, D(G(z)): 0.26
# Epoch [124/300], Step [600/600], d_loss: 1.3838, g_loss: 1.0466, D(x): 0.69, D(G(z)): 0.48
# Saving fake_images-0125.png
# Epoch [125/300], Step [200/600], d_loss: 0.7638, g_loss: 1.3399, D(x): 0.77, D(G(z)): 0.31
# Epoch [125/300], Step [400/600], d_loss: 0.9670, g_loss: 1.6476, D(x): 0.73, D(G(z)): 0.33
# Epoch [125/300], Step [600/600], d_loss: 1.0909, g_loss: 1.2231, D(x): 0.69, D(G(z)): 0.37
# Saving fake_images-0126.png
# Epoch [126/300], Step [200/600], d_loss: 0.7555, g_loss: 1.6715, D(x): 0.74, D(G(z)): 0.25
# Epoch [126/300], Step [400/600], d_loss: 0.7583, g_loss: 2.0376, D(x): 0.73, D(G(z)): 0.26
# Epoch [126/300], Step [600/600], d_loss: 0.7565, g_loss: 1.9029, D(x): 0.77, D(G(z)): 0.25
# Saving fake_images-0127.png
# Epoch [127/300], Step [200/600], d_loss: 0.9278, g_loss: 1.5542, D(x): 0.75, D(G(z)): 0.34
# Epoch [127/300], Step [400/600], d_loss: 0.9069, g_loss: 1.2915, D(x): 0.79, D(G(z)): 0.38
# Epoch [127/300], Step [600/600], d_loss: 0.9021, g_loss: 1.7813, D(x): 0.72, D(G(z)): 0.30
# Saving fake_images-0128.png
# Epoch [128/300], Step [200/600], d_loss: 1.0987, g_loss: 1.5033, D(x): 0.60, D(G(z)): 0.28
# Epoch [128/300], Step [400/600], d_loss: 0.7959, g_loss: 1.5241, D(x): 0.79, D(G(z)): 0.33
# Epoch [128/300], Step [600/600], d_loss: 0.9493, g_loss: 1.7924, D(x): 0.68, D(G(z)): 0.30
# Saving fake_images-0129.png
# Epoch [129/300], Step [200/600], d_loss: 0.8981, g_loss: 1.5644, D(x): 0.66, D(G(z)): 0.25
# Epoch [129/300], Step [400/600], d_loss: 0.9772, g_loss: 1.3425, D(x): 0.73, D(G(z)): 0.36
# Epoch [129/300], Step [600/600], d_loss: 0.7761, g_loss: 1.6647, D(x): 0.78, D(G(z)): 0.32
# Saving fake_images-0130.png
# Epoch [130/300], Step [200/600], d_loss: 0.9943, g_loss: 1.8701, D(x): 0.69, D(G(z)): 0.32
# Epoch [130/300], Step [400/600], d_loss: 0.8993, g_loss: 2.0719, D(x): 0.65, D(G(z)): 0.23
# Epoch [130/300], Step [600/600], d_loss: 1.1817, g_loss: 1.2347, D(x): 0.64, D(G(z)): 0.36
# Saving fake_images-0131.png
# Epoch [131/300], Step [200/600], d_loss: 0.6374, g_loss: 2.0005, D(x): 0.75, D(G(z)): 0.21
# Epoch [131/300], Step [400/600], d_loss: 0.9701, g_loss: 1.4551, D(x): 0.69, D(G(z)): 0.32
# Epoch [131/300], Step [600/600], d_loss: 1.0696, g_loss: 1.4156, D(x): 0.64, D(G(z)): 0.29
# Saving fake_images-0132.png
# Epoch [132/300], Step [200/600], d_loss: 0.9104, g_loss: 1.1449, D(x): 0.63, D(G(z)): 0.22
# Epoch [132/300], Step [400/600], d_loss: 0.8886, g_loss: 1.3084, D(x): 0.67, D(G(z)): 0.25
# Epoch [132/300], Step [600/600], d_loss: 1.1568, g_loss: 1.2704, D(x): 0.78, D(G(z)): 0.46
# Saving fake_images-0133.png
# Epoch [133/300], Step [200/600], d_loss: 0.8713, g_loss: 1.9727, D(x): 0.66, D(G(z)): 0.22
# Epoch [133/300], Step [400/600], d_loss: 0.7661, g_loss: 1.7019, D(x): 0.79, D(G(z)): 0.32
# Epoch [133/300], Step [600/600], d_loss: 0.8478, g_loss: 2.0900, D(x): 0.70, D(G(z)): 0.27
# Saving fake_images-0134.png
# Epoch [134/300], Step [200/600], d_loss: 0.8721, g_loss: 1.5540, D(x): 0.76, D(G(z)): 0.34
# Epoch [134/300], Step [400/600], d_loss: 0.8675, g_loss: 2.0661, D(x): 0.65, D(G(z)): 0.20
# Epoch [134/300], Step [600/600], d_loss: 0.8716, g_loss: 2.0646, D(x): 0.66, D(G(z)): 0.21
# Saving fake_images-0135.png
# Epoch [135/300], Step [200/600], d_loss: 0.7867, g_loss: 1.4104, D(x): 0.80, D(G(z)): 0.31
# Epoch [135/300], Step [400/600], d_loss: 0.7830, g_loss: 1.4331, D(x): 0.77, D(G(z)): 0.32
# Epoch [135/300], Step [600/600], d_loss: 1.0093, g_loss: 1.3441, D(x): 0.63, D(G(z)): 0.25
# Saving fake_images-0136.png
# Epoch [136/300], Step [200/600], d_loss: 0.9812, g_loss: 1.6837, D(x): 0.60, D(G(z)): 0.21
# Epoch [136/300], Step [400/600], d_loss: 1.0769, g_loss: 1.7455, D(x): 0.58, D(G(z)): 0.21
# Epoch [136/300], Step [600/600], d_loss: 0.9760, g_loss: 1.2914, D(x): 0.72, D(G(z)): 0.38
# Saving fake_images-0137.png
# Epoch [137/300], Step [200/600], d_loss: 0.8798, g_loss: 1.4020, D(x): 0.68, D(G(z)): 0.26
# Epoch [137/300], Step [400/600], d_loss: 0.7021, g_loss: 1.8341, D(x): 0.76, D(G(z)): 0.25
# Epoch [137/300], Step [600/600], d_loss: 0.7564, g_loss: 1.7238, D(x): 0.81, D(G(z)): 0.30
# Saving fake_images-0138.png
# Epoch [138/300], Step [200/600], d_loss: 0.9177, g_loss: 1.2497, D(x): 0.73, D(G(z)): 0.34
# Epoch [138/300], Step [400/600], d_loss: 1.0001, g_loss: 1.5781, D(x): 0.69, D(G(z)): 0.30
# Epoch [138/300], Step [600/600], d_loss: 0.8909, g_loss: 1.5922, D(x): 0.70, D(G(z)): 0.29
# Saving fake_images-0139.png
# Epoch [139/300], Step [200/600], d_loss: 0.8828, g_loss: 1.4203, D(x): 0.67, D(G(z)): 0.27
# Epoch [139/300], Step [400/600], d_loss: 0.8799, g_loss: 1.5469, D(x): 0.66, D(G(z)): 0.27
# Epoch [139/300], Step [600/600], d_loss: 1.0178, g_loss: 1.3139, D(x): 0.73, D(G(z)): 0.40
# Saving fake_images-0140.png
# Epoch [140/300], Step [200/600], d_loss: 0.9295, g_loss: 1.5740, D(x): 0.76, D(G(z)): 0.38
# Epoch [140/300], Step [400/600], d_loss: 0.9665, g_loss: 1.6432, D(x): 0.67, D(G(z)): 0.30
# Epoch [140/300], Step [600/600], d_loss: 0.8169, g_loss: 1.5310, D(x): 0.73, D(G(z)): 0.28
# Saving fake_images-0141.png
# Epoch [141/300], Step [200/600], d_loss: 0.8271, g_loss: 1.7179, D(x): 0.73, D(G(z)): 0.29
# Epoch [141/300], Step [400/600], d_loss: 0.7915, g_loss: 1.8028, D(x): 0.76, D(G(z)): 0.30
# Epoch [141/300], Step [600/600], d_loss: 1.1612, g_loss: 1.5836, D(x): 0.65, D(G(z)): 0.35
# Saving fake_images-0142.png
# Epoch [142/300], Step [200/600], d_loss: 0.7151, g_loss: 1.7885, D(x): 0.74, D(G(z)): 0.24
# Epoch [142/300], Step [400/600], d_loss: 0.8845, g_loss: 1.6175, D(x): 0.74, D(G(z)): 0.31
# Epoch [142/300], Step [600/600], d_loss: 0.8146, g_loss: 2.5378, D(x): 0.70, D(G(z)): 0.26
# Saving fake_images-0143.png
# Epoch [143/300], Step [200/600], d_loss: 0.7091, g_loss: 1.8288, D(x): 0.76, D(G(z)): 0.25
# Epoch [143/300], Step [400/600], d_loss: 0.8996, g_loss: 1.8481, D(x): 0.68, D(G(z)): 0.27
# Epoch [143/300], Step [600/600], d_loss: 0.8848, g_loss: 1.8890, D(x): 0.69, D(G(z)): 0.28
# Saving fake_images-0144.png
# Epoch [144/300], Step [200/600], d_loss: 0.9352, g_loss: 1.4657, D(x): 0.73, D(G(z)): 0.33
# Epoch [144/300], Step [400/600], d_loss: 0.8317, g_loss: 1.8274, D(x): 0.72, D(G(z)): 0.29
# Epoch [144/300], Step [600/600], d_loss: 0.9320, g_loss: 1.7416, D(x): 0.71, D(G(z)): 0.32
# Saving fake_images-0145.png
# Epoch [145/300], Step [200/600], d_loss: 0.8903, g_loss: 1.8449, D(x): 0.65, D(G(z)): 0.23
# Epoch [145/300], Step [400/600], d_loss: 0.8869, g_loss: 1.5357, D(x): 0.75, D(G(z)): 0.34
# Epoch [145/300], Step [600/600], d_loss: 0.9107, g_loss: 1.7011, D(x): 0.68, D(G(z)): 0.27
# Saving fake_images-0146.png
# Epoch [146/300], Step [200/600], d_loss: 0.8914, g_loss: 1.7677, D(x): 0.77, D(G(z)): 0.37
# Epoch [146/300], Step [400/600], d_loss: 1.0750, g_loss: 1.5306, D(x): 0.60, D(G(z)): 0.26
# Epoch [146/300], Step [600/600], d_loss: 1.0872, g_loss: 1.8180, D(x): 0.62, D(G(z)): 0.25
# Saving fake_images-0147.png
# Epoch [147/300], Step [200/600], d_loss: 1.0385, g_loss: 1.7037, D(x): 0.73, D(G(z)): 0.39
# Epoch [147/300], Step [400/600], d_loss: 0.9056, g_loss: 1.5465, D(x): 0.72, D(G(z)): 0.32
# Epoch [147/300], Step [600/600], d_loss: 0.8288, g_loss: 1.4466, D(x): 0.77, D(G(z)): 0.35
# Saving fake_images-0148.png
# Epoch [148/300], Step [200/600], d_loss: 0.8995, g_loss: 1.5244, D(x): 0.79, D(G(z)): 0.37
# Epoch [148/300], Step [400/600], d_loss: 0.8165, g_loss: 1.5910, D(x): 0.73, D(G(z)): 0.28
# Epoch [148/300], Step [600/600], d_loss: 0.8780, g_loss: 1.5424, D(x): 0.70, D(G(z)): 0.28
# Saving fake_images-0149.png
# Epoch [149/300], Step [200/600], d_loss: 0.9627, g_loss: 1.0688, D(x): 0.83, D(G(z)): 0.44
# Epoch [149/300], Step [400/600], d_loss: 1.0365, g_loss: 1.4078, D(x): 0.59, D(G(z)): 0.24
# Epoch [149/300], Step [600/600], d_loss: 0.8302, g_loss: 1.4504, D(x): 0.70, D(G(z)): 0.27
# Saving fake_images-0150.png
# Epoch [150/300], Step [200/600], d_loss: 1.0784, g_loss: 1.7617, D(x): 0.72, D(G(z)): 0.39
# Epoch [150/300], Step [400/600], d_loss: 1.1486, g_loss: 1.4659, D(x): 0.71, D(G(z)): 0.40
# Epoch [150/300], Step [600/600], d_loss: 1.1657, g_loss: 1.5435, D(x): 0.69, D(G(z)): 0.43
# Saving fake_images-0151.png
# Epoch [151/300], Step [200/600], d_loss: 0.6912, g_loss: 1.8613, D(x): 0.78, D(G(z)): 0.28
# Epoch [151/300], Step [400/600], d_loss: 0.9754, g_loss: 1.4849, D(x): 0.69, D(G(z)): 0.30
# Epoch [151/300], Step [600/600], d_loss: 0.8817, g_loss: 1.5759, D(x): 0.75, D(G(z)): 0.35
# Saving fake_images-0152.png
# Epoch [152/300], Step [200/600], d_loss: 0.8330, g_loss: 1.7679, D(x): 0.73, D(G(z)): 0.32
# Epoch [152/300], Step [400/600], d_loss: 1.0657, g_loss: 1.9041, D(x): 0.58, D(G(z)): 0.21
# Epoch [152/300], Step [600/600], d_loss: 0.9074, g_loss: 1.2636, D(x): 0.71, D(G(z)): 0.30
# Saving fake_images-0153.png
# Epoch [153/300], Step [200/600], d_loss: 0.7697, g_loss: 1.7628, D(x): 0.70, D(G(z)): 0.24
# Epoch [153/300], Step [400/600], d_loss: 0.8546, g_loss: 1.7693, D(x): 0.72, D(G(z)): 0.30
# Epoch [153/300], Step [600/600], d_loss: 0.7921, g_loss: 1.6627, D(x): 0.70, D(G(z)): 0.24
# Saving fake_images-0154.png
# Epoch [154/300], Step [200/600], d_loss: 0.9600, g_loss: 1.3199, D(x): 0.66, D(G(z)): 0.31
# Epoch [154/300], Step [400/600], d_loss: 1.0114, g_loss: 1.2024, D(x): 0.68, D(G(z)): 0.34
# Epoch [154/300], Step [600/600], d_loss: 0.8793, g_loss: 1.6940, D(x): 0.75, D(G(z)): 0.35
# Saving fake_images-0155.png
# Epoch [155/300], Step [200/600], d_loss: 0.7504, g_loss: 1.6774, D(x): 0.72, D(G(z)): 0.25
# Epoch [155/300], Step [400/600], d_loss: 1.0721, g_loss: 1.5378, D(x): 0.61, D(G(z)): 0.29
# Epoch [155/300], Step [600/600], d_loss: 0.9728, g_loss: 1.5709, D(x): 0.72, D(G(z)): 0.36
# Saving fake_images-0156.png
# Epoch [156/300], Step [200/600], d_loss: 0.9685, g_loss: 1.8878, D(x): 0.60, D(G(z)): 0.22
# Epoch [156/300], Step [400/600], d_loss: 0.8208, g_loss: 2.0344, D(x): 0.71, D(G(z)): 0.28
# Epoch [156/300], Step [600/600], d_loss: 0.9699, g_loss: 1.8683, D(x): 0.71, D(G(z)): 0.33
# Saving fake_images-0157.png
# Epoch [157/300], Step [200/600], d_loss: 1.1519, g_loss: 1.5695, D(x): 0.61, D(G(z)): 0.31
# Epoch [157/300], Step [400/600], d_loss: 0.9061, g_loss: 1.2079, D(x): 0.69, D(G(z)): 0.30
# Epoch [157/300], Step [600/600], d_loss: 1.0184, g_loss: 1.3532, D(x): 0.65, D(G(z)): 0.32
# Saving fake_images-0158.png
# Epoch [158/300], Step [200/600], d_loss: 1.0277, g_loss: 1.2801, D(x): 0.62, D(G(z)): 0.30
# Epoch [158/300], Step [400/600], d_loss: 0.9830, g_loss: 1.2828, D(x): 0.66, D(G(z)): 0.29
# Epoch [158/300], Step [600/600], d_loss: 0.8993, g_loss: 1.4549, D(x): 0.72, D(G(z)): 0.33
# Saving fake_images-0159.png
# Epoch [159/300], Step [200/600], d_loss: 0.8993, g_loss: 1.7625, D(x): 0.65, D(G(z)): 0.24
# Epoch [159/300], Step [400/600], d_loss: 0.8668, g_loss: 1.8750, D(x): 0.65, D(G(z)): 0.21
# Epoch [159/300], Step [600/600], d_loss: 0.9482, g_loss: 1.6062, D(x): 0.70, D(G(z)): 0.34
# Saving fake_images-0160.png
# Epoch [160/300], Step [200/600], d_loss: 1.0087, g_loss: 1.0504, D(x): 0.70, D(G(z)): 0.35
# ...
# Epoch [238/300], Step [400/600], d_loss: 0.8385, g_loss: 1.4617, D(x): 0.66, D(G(z)): 0.25
# Epoch [238/300], Step [600/600], d_loss: 1.0297, g_loss: 1.3910, D(x): 0.64, D(G(z)): 0.31
# Saving fake_images-0239.png
# Epoch [239/300], Step [200/600], d_loss: 0.9738, g_loss: 1.4655, D(x): 0.79, D(G(z)): 0.45
# Epoch [239/300], Step [400/600], d_loss: 0.9822, g_loss: 1.3827, D(x): 0.68, D(G(z)): 0.32
# Epoch [239/300], Step [600/600], d_loss: 0.8371, g_loss: 1.4418, D(x): 0.73, D(G(z)): 0.32
# Saving fake_images-0240.png
# Epoch [240/300], Step [200/600], d_loss: 0.9438, g_loss: 1.6675, D(x): 0.71, D(G(z)): 0.36
# Epoch [240/300], Step [400/600], d_loss: 0.9702, g_loss: 1.5780, D(x): 0.66, D(G(z)): 0.28
# Epoch [240/300], Step [600/600], d_loss: 0.7939, g_loss: 1.4147, D(x): 0.74, D(G(z)): 0.30
# Saving fake_images-0241.png
# Epoch [241/300], Step [200/600], d_loss: 0.9373, g_loss: 1.4041, D(x): 0.70, D(G(z)): 0.33
# Epoch [241/300], Step [400/600], d_loss: 0.9040, g_loss: 1.6928, D(x): 0.64, D(G(z)): 0.26
# Epoch [241/300], Step [600/600], d_loss: 0.9446, g_loss: 1.3645, D(x): 0.71, D(G(z)): 0.34
# Saving fake_images-0242.png
# Epoch [242/300], Step [200/600], d_loss: 0.8527, g_loss: 1.5152, D(x): 0.69, D(G(z)): 0.27
# Epoch [242/300], Step [400/600], d_loss: 0.8440, g_loss: 1.5540, D(x): 0.73, D(G(z)): 0.31
# Epoch [242/300], Step [600/600], d_loss: 1.0209, g_loss: 1.3834, D(x): 0.61, D(G(z)): 0.27
# Saving fake_images-0243.png
# Epoch [243/300], Step [200/600], d_loss: 0.9262, g_loss: 1.5738, D(x): 0.71, D(G(z)): 0.33
# Epoch [243/300], Step [400/600], d_loss: 0.9663, g_loss: 1.6998, D(x): 0.67, D(G(z)): 0.29
# Epoch [243/300], Step [600/600], d_loss: 0.8118, g_loss: 1.3289, D(x): 0.72, D(G(z)): 0.29
# Saving fake_images-0244.png
# Epoch [244/300], Step [200/600], d_loss: 0.8750, g_loss: 1.4296, D(x): 0.73, D(G(z)): 0.32
# Epoch [244/300], Step [400/600], d_loss: 0.9052, g_loss: 1.2289, D(x): 0.69, D(G(z)): 0.30
# Epoch [244/300], Step [600/600], d_loss: 0.9904, g_loss: 1.4102, D(x): 0.67, D(G(z)): 0.33
# Saving fake_images-0245.png
# Epoch [245/300], Step [200/600], d_loss: 1.0836, g_loss: 1.2543, D(x): 0.64, D(G(z)): 0.36
# Epoch [245/300], Step [400/600], d_loss: 0.8626, g_loss: 1.3805, D(x): 0.79, D(G(z)): 0.37
# Epoch [245/300], Step [600/600], d_loss: 0.8388, g_loss: 1.4269, D(x): 0.74, D(G(z)): 0.32
# Saving fake_images-0246.png
# Epoch [246/300], Step [200/600], d_loss: 0.8208, g_loss: 1.6141, D(x): 0.74, D(G(z)): 0.31
# Epoch [246/300], Step [400/600], d_loss: 1.0147, g_loss: 1.5765, D(x): 0.62, D(G(z)): 0.25
# Epoch [246/300], Step [600/600], d_loss: 0.9352, g_loss: 1.5119, D(x): 0.68, D(G(z)): 0.31
# Saving fake_images-0247.png
# Epoch [247/300], Step [200/600], d_loss: 1.0884, g_loss: 1.7152, D(x): 0.61, D(G(z)): 0.27
# Epoch [247/300], Step [400/600], d_loss: 0.9778, g_loss: 1.6920, D(x): 0.65, D(G(z)): 0.29
# Epoch [247/300], Step [600/600], d_loss: 1.1628, g_loss: 1.5086, D(x): 0.60, D(G(z)): 0.32
# Saving fake_images-0248.png
# Epoch [248/300], Step [200/600], d_loss: 0.9474, g_loss: 1.2059, D(x): 0.70, D(G(z)): 0.35
# Epoch [248/300], Step [400/600], d_loss: 0.8566, g_loss: 1.5925, D(x): 0.72, D(G(z)): 0.31
# Epoch [248/300], Step [600/600], d_loss: 1.0016, g_loss: 1.1994, D(x): 0.65, D(G(z)): 0.33
# Saving fake_images-0249.png
# Epoch [249/300], Step [200/600], d_loss: 0.9451, g_loss: 1.2611, D(x): 0.66, D(G(z)): 0.27
# Epoch [249/300], Step [400/600], d_loss: 1.0087, g_loss: 1.9602, D(x): 0.69, D(G(z)): 0.32
# Epoch [249/300], Step [600/600], d_loss: 0.9920, g_loss: 1.3282, D(x): 0.77, D(G(z)): 0.40
# Saving fake_images-0250.png
# Epoch [250/300], Step [200/600], d_loss: 0.9484, g_loss: 1.5121, D(x): 0.68, D(G(z)): 0.32
# Epoch [250/300], Step [400/600], d_loss: 1.0494, g_loss: 1.5844, D(x): 0.63, D(G(z)): 0.33
# Epoch [250/300], Step [600/600], d_loss: 0.9207, g_loss: 1.6928, D(x): 0.69, D(G(z)): 0.31
# Saving fake_images-0251.png
# Epoch [251/300], Step [200/600], d_loss: 0.9681, g_loss: 1.9422, D(x): 0.69, D(G(z)): 0.33
# Epoch [251/300], Step [400/600], d_loss: 0.9580, g_loss: 1.5088, D(x): 0.67, D(G(z)): 0.30
# Epoch [251/300], Step [600/600], d_loss: 0.9291, g_loss: 1.3711, D(x): 0.70, D(G(z)): 0.33
# Saving fake_images-0252.png
# Epoch [252/300], Step [200/600], d_loss: 0.9286, g_loss: 1.7656, D(x): 0.69, D(G(z)): 0.27
# Epoch [252/300], Step [400/600], d_loss: 0.9501, g_loss: 1.2032, D(x): 0.69, D(G(z)): 0.33
# Epoch [252/300], Step [600/600], d_loss: 0.9519, g_loss: 1.3065, D(x): 0.70, D(G(z)): 0.34
# Saving fake_images-0253.png
# Epoch [253/300], Step [200/600], d_loss: 0.7994, g_loss: 1.6915, D(x): 0.70, D(G(z)): 0.25
# Epoch [253/300], Step [400/600], d_loss: 0.9254, g_loss: 1.3980, D(x): 0.66, D(G(z)): 0.28
# Epoch [253/300], Step [600/600], d_loss: 0.9529, g_loss: 1.7824, D(x): 0.62, D(G(z)): 0.26
# Saving fake_images-0254.png
# Epoch [254/300], Step [200/600], d_loss: 0.9964, g_loss: 1.7045, D(x): 0.65, D(G(z)): 0.29
# Epoch [254/300], Step [400/600], d_loss: 1.0384, g_loss: 1.4592, D(x): 0.66, D(G(z)): 0.34
# Epoch [254/300], Step [600/600], d_loss: 1.0977, g_loss: 1.4102, D(x): 0.66, D(G(z)): 0.37
# Saving fake_images-0255.png
# Epoch [255/300], Step [200/600], d_loss: 0.9209, g_loss: 1.4801, D(x): 0.67, D(G(z)): 0.27
# Epoch [255/300], Step [400/600], d_loss: 0.8544, g_loss: 1.6940, D(x): 0.72, D(G(z)): 0.30
# Epoch [255/300], Step [600/600], d_loss: 0.9047, g_loss: 1.6406, D(x): 0.69, D(G(z)): 0.30
# Saving fake_images-0256.png
# Epoch [256/300], Step [200/600], d_loss: 0.8590, g_loss: 1.6582, D(x): 0.68, D(G(z)): 0.27
# Epoch [256/300], Step [400/600], d_loss: 0.8502, g_loss: 1.5344, D(x): 0.72, D(G(z)): 0.28
# Epoch [256/300], Step [600/600], d_loss: 1.0612, g_loss: 1.6006, D(x): 0.73, D(G(z)): 0.39
# Saving fake_images-0257.png
# Epoch [257/300], Step [200/600], d_loss: 0.9654, g_loss: 1.4720, D(x): 0.71, D(G(z)): 0.30
# Epoch [257/300], Step [400/600], d_loss: 0.9290, g_loss: 1.5044, D(x): 0.70, D(G(z)): 0.31
# Epoch [257/300], Step [600/600], d_loss: 1.0149, g_loss: 1.6153, D(x): 0.65, D(G(z)): 0.33
# Saving fake_images-0258.png
# Epoch [258/300], Step [200/600], d_loss: 0.8299, g_loss: 1.2363, D(x): 0.76, D(G(z)): 0.32
# Epoch [258/300], Step [400/600], d_loss: 0.8142, g_loss: 1.5841, D(x): 0.69, D(G(z)): 0.24
# Epoch [258/300], Step [600/600], d_loss: 0.8863, g_loss: 1.7026, D(x): 0.70, D(G(z)): 0.30
# Saving fake_images-0259.png
# Epoch [259/300], Step [200/600], d_loss: 0.9450, g_loss: 1.6678, D(x): 0.71, D(G(z)): 0.33
# Epoch [259/300], Step [400/600], d_loss: 0.9240, g_loss: 1.3767, D(x): 0.64, D(G(z)): 0.26
# Epoch [259/300], Step [600/600], d_loss: 0.7159, g_loss: 1.6924, D(x): 0.79, D(G(z)): 0.29
# Saving fake_images-0260.png
# Epoch [260/300], Step [200/600], d_loss: 0.9532, g_loss: 1.4337, D(x): 0.72, D(G(z)): 0.33
# Epoch [260/300], Step [400/600], d_loss: 0.8874, g_loss: 1.4634, D(x): 0.71, D(G(z)): 0.31
# Epoch [260/300], Step [600/600], d_loss: 0.8797, g_loss: 1.2586, D(x): 0.74, D(G(z)): 0.35
# Saving fake_images-0261.png
# Epoch [261/300], Step [200/600], d_loss: 0.9974, g_loss: 1.5034, D(x): 0.66, D(G(z)): 0.33
# Epoch [261/300], Step [400/600], d_loss: 1.0774, g_loss: 1.2841, D(x): 0.73, D(G(z)): 0.43
# Epoch [261/300], Step [600/600], d_loss: 0.9621, g_loss: 1.5890, D(x): 0.66, D(G(z)): 0.28
# Saving fake_images-0262.png
# Epoch [262/300], Step [200/600], d_loss: 0.7456, g_loss: 1.9781, D(x): 0.75, D(G(z)): 0.25
# Epoch [262/300], Step [400/600], d_loss: 0.9936, g_loss: 1.6380, D(x): 0.64, D(G(z)): 0.28
# Epoch [262/300], Step [600/600], d_loss: 1.0237, g_loss: 1.6067, D(x): 0.59, D(G(z)): 0.26
# Saving fake_images-0263.png
# Epoch [263/300], Step [200/600], d_loss: 1.1059, g_loss: 1.6682, D(x): 0.62, D(G(z)): 0.31
# Epoch [263/300], Step [400/600], d_loss: 0.9372, g_loss: 1.3816, D(x): 0.71, D(G(z)): 0.33
# Epoch [263/300], Step [600/600], d_loss: 0.8598, g_loss: 1.3968, D(x): 0.76, D(G(z)): 0.34
# Saving fake_images-0264.png
# Epoch [264/300], Step [200/600], d_loss: 1.0754, g_loss: 1.1262, D(x): 0.67, D(G(z)): 0.37
# Epoch [264/300], Step [400/600], d_loss: 0.9587, g_loss: 1.5425, D(x): 0.76, D(G(z)): 0.39
# Epoch [264/300], Step [600/600], d_loss: 0.8809, g_loss: 1.5975, D(x): 0.70, D(G(z)): 0.29
# Saving fake_images-0265.png
# Epoch [265/300], Step [200/600], d_loss: 0.9306, g_loss: 1.7027, D(x): 0.69, D(G(z)): 0.32
# Epoch [265/300], Step [400/600], d_loss: 0.8776, g_loss: 1.4795, D(x): 0.70, D(G(z)): 0.29
# Epoch [265/300], Step [600/600], d_loss: 0.8395, g_loss: 1.6021, D(x): 0.73, D(G(z)): 0.29
# Saving fake_images-0266.png
# Epoch [266/300], Step [200/600], d_loss: 0.8934, g_loss: 1.5572, D(x): 0.66, D(G(z)): 0.26
# Epoch [266/300], Step [400/600], d_loss: 0.8842, g_loss: 1.8422, D(x): 0.71, D(G(z)): 0.28
# Epoch [266/300], Step [600/600], d_loss: 0.8142, g_loss: 1.7556, D(x): 0.70, D(G(z)): 0.26
# Saving fake_images-0267.png
# Epoch [267/300], Step [200/600], d_loss: 1.1423, g_loss: 1.4810, D(x): 0.57, D(G(z)): 0.26
# Epoch [267/300], Step [400/600], d_loss: 0.7898, g_loss: 1.6461, D(x): 0.69, D(G(z)): 0.23
# Epoch [267/300], Step [600/600], d_loss: 0.9994, g_loss: 1.4317, D(x): 0.63, D(G(z)): 0.30
# Saving fake_images-0268.png
# Epoch [268/300], Step [200/600], d_loss: 0.8567, g_loss: 1.3989, D(x): 0.67, D(G(z)): 0.25
# Epoch [268/300], Step [400/600], d_loss: 1.0682, g_loss: 1.1895, D(x): 0.69, D(G(z)): 0.37
# Epoch [268/300], Step [600/600], d_loss: 0.8546, g_loss: 1.4072, D(x): 0.69, D(G(z)): 0.26
# Saving fake_images-0269.png
# Epoch [269/300], Step [200/600], d_loss: 1.0330, g_loss: 1.7504, D(x): 0.61, D(G(z)): 0.29
# Epoch [269/300], Step [400/600], d_loss: 0.8943, g_loss: 1.2530, D(x): 0.74, D(G(z)): 0.34
# Epoch [269/300], Step [600/600], d_loss: 0.8567, g_loss: 1.5159, D(x): 0.68, D(G(z)): 0.28
# Saving fake_images-0270.png
# Epoch [270/300], Step [200/600], d_loss: 0.8247, g_loss: 1.7090, D(x): 0.73, D(G(z)): 0.31
# Epoch [270/300], Step [400/600], d_loss: 0.9136, g_loss: 1.5291, D(x): 0.72, D(G(z)): 0.32
# Epoch [270/300], Step [600/600], d_loss: 1.1426, g_loss: 1.5830, D(x): 0.55, D(G(z)): 0.25
# Saving fake_images-0271.png
# Epoch [271/300], Step [200/600], d_loss: 0.9379, g_loss: 1.1460, D(x): 0.74, D(G(z)): 0.39
# Epoch [271/300], Step [400/600], d_loss: 0.9285, g_loss: 1.2959, D(x): 0.72, D(G(z)): 0.35
# Epoch [271/300], Step [600/600], d_loss: 1.0279, g_loss: 1.4831, D(x): 0.68, D(G(z)): 0.35
# Saving fake_images-0272.png
# Epoch [272/300], Step [200/600], d_loss: 1.0653, g_loss: 1.4210, D(x): 0.72, D(G(z)): 0.40
# Epoch [272/300], Step [400/600], d_loss: 0.7675, g_loss: 1.5522, D(x): 0.72, D(G(z)): 0.26
# Epoch [272/300], Step [600/600], d_loss: 0.9555, g_loss: 1.7549, D(x): 0.73, D(G(z)): 0.33
# Saving fake_images-0273.png
# Epoch [273/300], Step [200/600], d_loss: 0.9608, g_loss: 1.3939, D(x): 0.70, D(G(z)): 0.32
# Epoch [273/300], Step [400/600], d_loss: 0.9344, g_loss: 1.8075, D(x): 0.66, D(G(z)): 0.28
# Epoch [273/300], Step [600/600], d_loss: 1.1495, g_loss: 1.2823, D(x): 0.67, D(G(z)): 0.38
# Saving fake_images-0274.png
# Epoch [274/300], Step [200/600], d_loss: 0.8917, g_loss: 1.6660, D(x): 0.64, D(G(z)): 0.24
# Epoch [274/300], Step [400/600], d_loss: 0.9743, g_loss: 1.7078, D(x): 0.72, D(G(z)): 0.33
# Epoch [274/300], Step [600/600], d_loss: 0.8409, g_loss: 1.6300, D(x): 0.64, D(G(z)): 0.20
# Saving fake_images-0275.png
# Epoch [275/300], Step [200/600], d_loss: 0.9266, g_loss: 1.4583, D(x): 0.70, D(G(z)): 0.32
# Epoch [275/300], Step [400/600], d_loss: 1.0924, g_loss: 1.2471, D(x): 0.66, D(G(z)): 0.38
# Epoch [275/300], Step [600/600], d_loss: 1.1497, g_loss: 1.3648, D(x): 0.69, D(G(z)): 0.40
# Saving fake_images-0276.png
# Epoch [276/300], Step [200/600], d_loss: 1.0156, g_loss: 1.0958, D(x): 0.77, D(G(z)): 0.41
# Epoch [276/300], Step [400/600], d_loss: 0.8493, g_loss: 1.7759, D(x): 0.69, D(G(z)): 0.28
# Epoch [276/300], Step [600/600], d_loss: 0.8339, g_loss: 1.4899, D(x): 0.76, D(G(z)): 0.31
# Saving fake_images-0277.png
# Epoch [277/300], Step [200/600], d_loss: 0.8525, g_loss: 1.7732, D(x): 0.74, D(G(z)): 0.33
# Epoch [277/300], Step [400/600], d_loss: 0.9711, g_loss: 1.5179, D(x): 0.65, D(G(z)): 0.28
# Epoch [277/300], Step [600/600], d_loss: 1.0752, g_loss: 1.3555, D(x): 0.69, D(G(z)): 0.37
# Saving fake_images-0278.png
# Epoch [278/300], Step [200/600], d_loss: 0.9610, g_loss: 1.5889, D(x): 0.64, D(G(z)): 0.28
# Epoch [278/300], Step [400/600], d_loss: 1.0429, g_loss: 1.3890, D(x): 0.60, D(G(z)): 0.27
# Epoch [278/300], Step [600/600], d_loss: 0.9759, g_loss: 1.3048, D(x): 0.67, D(G(z)): 0.33
# Saving fake_images-0279.png
# Epoch [279/300], Step [200/600], d_loss: 0.9028, g_loss: 1.3219, D(x): 0.71, D(G(z)): 0.31
# Epoch [279/300], Step [400/600], d_loss: 1.0197, g_loss: 1.2917, D(x): 0.68, D(G(z)): 0.36
# Epoch [279/300], Step [600/600], d_loss: 0.9350, g_loss: 1.3262, D(x): 0.72, D(G(z)): 0.35
# Saving fake_images-0280.png
# Epoch [280/300], Step [200/600], d_loss: 0.9286, g_loss: 1.7156, D(x): 0.64, D(G(z)): 0.25
# Epoch [280/300], Step [400/600], d_loss: 1.0254, g_loss: 1.4656, D(x): 0.60, D(G(z)): 0.26
# Epoch [280/300], Step [600/600], d_loss: 0.9201, g_loss: 1.8062, D(x): 0.67, D(G(z)): 0.28
# Saving fake_images-0281.png
# Epoch [281/300], Step [200/600], d_loss: 0.8007, g_loss: 1.5267, D(x): 0.77, D(G(z)): 0.33
# Epoch [281/300], Step [400/600], d_loss: 0.8310, g_loss: 1.5220, D(x): 0.72, D(G(z)): 0.27
# Epoch [281/300], Step [600/600], d_loss: 1.0119, g_loss: 1.7021, D(x): 0.68, D(G(z)): 0.30
# Saving fake_images-0282.png
# Epoch [282/300], Step [200/600], d_loss: 1.0407, g_loss: 1.3802, D(x): 0.70, D(G(z)): 0.36
# Epoch [282/300], Step [400/600], d_loss: 1.0648, g_loss: 1.4256, D(x): 0.63, D(G(z)): 0.30
# Epoch [282/300], Step [600/600], d_loss: 0.8105, g_loss: 1.2251, D(x): 0.73, D(G(z)): 0.30
# Saving fake_images-0283.png
# Epoch [283/300], Step [200/600], d_loss: 0.7854, g_loss: 1.4378, D(x): 0.72, D(G(z)): 0.25
# Epoch [283/300], Step [400/600], d_loss: 0.9978, g_loss: 1.3155, D(x): 0.67, D(G(z)): 0.33
# Epoch [283/300], Step [600/600], d_loss: 0.9270, g_loss: 1.3330, D(x): 0.71, D(G(z)): 0.33
# Saving fake_images-0284.png
# Epoch [284/300], Step [200/600], d_loss: 1.0342, g_loss: 1.9320, D(x): 0.65, D(G(z)): 0.33
# Epoch [284/300], Step [400/600], d_loss: 1.0055, g_loss: 1.0059, D(x): 0.69, D(G(z)): 0.35
# Epoch [284/300], Step [600/600], d_loss: 0.9296, g_loss: 1.5145, D(x): 0.66, D(G(z)): 0.30
# Saving fake_images-0285.png
# Epoch [285/300], Step [200/600], d_loss: 0.9760, g_loss: 1.3938, D(x): 0.68, D(G(z)): 0.35
# Epoch [285/300], Step [400/600], d_loss: 0.9548, g_loss: 1.2869, D(x): 0.67, D(G(z)): 0.30
# Epoch [285/300], Step [600/600], d_loss: 0.9958, g_loss: 1.3747, D(x): 0.73, D(G(z)): 0.37
# Saving fake_images-0286.png
# Epoch [286/300], Step [200/600], d_loss: 0.9596, g_loss: 1.7850, D(x): 0.66, D(G(z)): 0.28
# Epoch [286/300], Step [400/600], d_loss: 0.8992, g_loss: 1.7641, D(x): 0.72, D(G(z)): 0.30
# Epoch [286/300], Step [600/600], d_loss: 0.8952, g_loss: 1.8170, D(x): 0.64, D(G(z)): 0.25
# Saving fake_images-0287.png
# Epoch [287/300], Step [200/600], d_loss: 1.0303, g_loss: 1.6279, D(x): 0.71, D(G(z)): 0.38
# Epoch [287/300], Step [400/600], d_loss: 0.8942, g_loss: 1.7230, D(x): 0.68, D(G(z)): 0.26
# Epoch [287/300], Step [600/600], d_loss: 0.8444, g_loss: 1.7155, D(x): 0.70, D(G(z)): 0.27
# Saving fake_images-0288.png
# Epoch [288/300], Step [200/600], d_loss: 0.9759, g_loss: 1.2110, D(x): 0.71, D(G(z)): 0.38
# Epoch [288/300], Step [400/600], d_loss: 0.8962, g_loss: 1.8306, D(x): 0.73, D(G(z)): 0.31
# Epoch [288/300], Step [600/600], d_loss: 0.8694, g_loss: 1.7363, D(x): 0.67, D(G(z)): 0.26
# Saving fake_images-0289.png
# Epoch [289/300], Step [200/600], d_loss: 0.7956, g_loss: 1.3189, D(x): 0.71, D(G(z)): 0.29
# Epoch [289/300], Step [400/600], d_loss: 0.8666, g_loss: 1.3766, D(x): 0.72, D(G(z)): 0.31
# Epoch [289/300], Step [600/600], d_loss: 0.8329, g_loss: 1.7419, D(x): 0.74, D(G(z)): 0.30
# Saving fake_images-0290.png
# Epoch [290/300], Step [200/600], d_loss: 0.8210, g_loss: 1.6955, D(x): 0.77, D(G(z)): 0.33
# Epoch [290/300], Step [400/600], d_loss: 0.8534, g_loss: 1.3311, D(x): 0.69, D(G(z)): 0.28
# Epoch [290/300], Step [600/600], d_loss: 1.0162, g_loss: 1.7041, D(x): 0.74, D(G(z)): 0.39
# Saving fake_images-0291.png
# Epoch [291/300], Step [200/600], d_loss: 0.8968, g_loss: 1.3895, D(x): 0.67, D(G(z)): 0.24

# %%
# Save the model checkpoints 
torch.save(G.state_dict(), 'G.ckpt')
torch.save(D.state_dict(), 'D.ckpt')

# %%
Image('./samples/fake_images-0010.png')

# %%
Image('./samples/fake_images-0050.png')

# %%
Image('./samples/fake_images-0100.png')

# %%
Image('./samples/fake_images-0290.png')

# %%
plt.plot(d_losses, '-')
plt.plot(g_losses, '-')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['Discriminator', 'Generator'])
plt.title('Losses');

# %%
plt.plot(real_scores, '-')
plt.plot(fake_scores, '-')
plt.xlabel('epoch')
plt.ylabel('score')
plt.legend(['Real Score', 'Fake score'])
plt.title('Scores');

# %%
import cv2
import os
from IPython.display import FileLink

vid_fname = 'gans_training.avi'

files = [os.path.join(sample_dir, f) for f in os.listdir(sample_dir) if 'fake_images' in f]
files.sort()

out = cv2.VideoWriter(vid_fname,cv2.VideoWriter_fourcc(*'MP4V'), 8, (302,302))
[out.write(cv2.imread(fname)) for fname in files]
out.release()
FileLink('gans_training.avi')
# Out:
# /content/gans_training.avi
